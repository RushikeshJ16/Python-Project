# %% [markdown]
# # Libraries in Data Analytics
#
# 1. Pandas(Python Data Analysis)
# 2. Numpy(Numerical Python)
# 3. Matplotlib(Library used to visualize the plots)
# 4. Seaborn(Its also a visualization library but more colorful and interactive)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("cab_rides.csv")
print(type(df))

#data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068    NaN               1.0  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
# [693071 rows x 10 columns]

# %%
df.shape #every row is corresponding to one uber trip
#(no_of_rows,no_of_columns)
# Out:
# (693071, 10)

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name'],
#       dtype='object')

# %%
df['date_time'] = pd.to_datetime(df['time_stamp']/1000, unit='s')

# %%
print(dir(df))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_add_numeric_operations', '_agg_by_level', '_agg_examples_doc', '_agg_summary_and_see_also_doc', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_attrs', '_box_col_values', '_can_fast_transpose', '_check_inplace_and_allows_duplicate_labels', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_combine_frame', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_from_arguments', '_construct_result', '_constructor', '_constructor_sliced', '_convert', '_count_level', '_data', '_dir_additions', '_dir_deletions', '_dispatch_frame_op', '_drop_axis', '_drop_labels_or_levels', '_ensure_valid_index', '_find_valid_index', '_flags', '_from_arrays', '_from_mgr', '_get_agg_axis', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cleaned_column_resolvers', '_get_column_array', '_get_index_resolvers', '_get_item_cache', '_get_label_or_level_values', '_get_numeric_data', '_get_value', '_getitem_bool_array', '_getitem_multilevel', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_info_repr', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_copy', '_is_homogeneous_type', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_iset_item', '_iset_item_mgr', '_iset_not_inplace', '_item_cache', '_iter_column_arrays', '_ixs', '_join_compat', '_logical_func', '_logical_method', '_maybe_cache_changed', '_maybe_update_cacher', '_metadata', '_mgr', '_min_count_stat_function', '_needs_reindex_multi', '_protect_consolidate', '_reduce', '_reduce_axis1', '_reindex_axes', '_reindex_columns', '_reindex_index', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_columnwise', '_repr_data_resource_', '_repr_fits_horizontal_', '_repr_fits_vertical_', '_repr_html_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_sanitize_column', '_series', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_item', '_set_item_frame_value', '_set_item_mgr', '_set_value', '_setitem_array', '_setitem_frame', '_setitem_slice', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_to_dict_of_blocks', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'append', 'apply', 'applymap', 'asfreq', 'asof', 'assign', 'astype', 'at', 'at_time', 'attrs', 'axe ...

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'date_time'],
#       dtype='object')

# %%
# to check if there are duplicates in my data

df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068    NaN               1.0  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 693066 2018-12-01 23:53:05.533999872
# 693067 2018-12-01 23:53:05.533999872
# 693068 2018-12-01 23:53:05.533999872
# 693069 2018-12-01 23:53:05.533999872
# 693070 2018-12-01 23:53:05.533999872
#
# [693071 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# date_time               0
# dtype: int64

# %%
df['distance'].describe()
# Out:
# count    693071.000000
# mean          2.189430
# std           1.138937
# min           0.020000
# 25%           1.280000
# 50%           2.160000
# 75%           2.920000
# max           7.860000
# Name: distance, dtype: float64

# %%
df.distance.describe()
# Out:
# count    693071.000000
# mean          2.189430
# std           1.138937
# min           0.020000
# 25%           1.280000
# 50%           2.160000
# 75%           2.920000
# max           7.860000
# Name: distance, dtype: float64

# %%
value_distance=df.distance.value_counts()
value_distance
# Out:
# 2.66    9174
# 2.32    9127
# 2.84    8562
# 1.41    7884
# 1.25    7434
#         ...
# 5.06       6
# 5.03       6
# 4.87       6
# 4.99       6
# 4.89       6
# Name: distance, Length: 549, dtype: int64

# %%
print(len(value_distance))
# Out:
# 549

# %%
top_10_value_dis=value_distance.iloc[:10] 
top_10_value_dis
# Out:
# 2.66    9174
# 2.32    9127
# 2.84    8562
# 1.41    7884
# 1.25    7434
# 1.16    7333
# 1.08    7251
# 1.34    7105
# 1.50    7067
# 1.35    6952
# Name: distance, dtype: int64

# %%
df1=df.iloc[:,0:2]
df1
# Out:
#         distance cab_type
# 0           0.44     Lyft
# 1           0.44     Lyft
# 2           0.44     Lyft
# 3           0.44     Lyft
# 4           0.44     Lyft
# ...          ...      ...
# 693066      1.00     Uber
# 693067      1.00     Uber
# 693068      1.00     Uber
# 693069      1.00     Uber
# 693070      1.00     Uber
#
# [693071 rows x 2 columns]

# %%
df1=df.iloc[0:5,0:2]
df1
# Out:
#    distance cab_type
# 0      0.44     Lyft
# 1      0.44     Lyft
# 2      0.44     Lyft
# 3      0.44     Lyft
# 4      0.44     Lyft

# %%
df1=df.iloc[:,:]
df1
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068    NaN               1.0  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 693066 2018-12-01 23:53:05.533999872
# 693067 2018-12-01 23:53:05.533999872
# 693068 2018-12-01 23:53:05.533999872
# 693069 2018-12-01 23:53:05.533999872
# 693070 2018-12-01 23:53:05.533999872
#
# [693071 rows x 11 columns]

# %%
df2=df.loc[df.distance==0.44]
df2
# Out:
#         distance cab_type     time_stamp    destination              source  \
# 0           0.44     Lyft  1544952607890  North Station    Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station    Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station    Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station    Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station    Haymarket Square
# ...          ...      ...            ...            ...                 ...
# 691972      0.44     Lyft  1543898576366  South Station  Financial District
# 691973      0.44     Lyft  1543898576366  South Station  Financial District
# 691974      0.44     Lyft  1543898576366  South Station  Financial District
# 691975      0.44     Lyft  1543898576366  South Station  Financial District
# 691976      0.44     Lyft  1543768683666  South Station  Financial District
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 691972    5.0               1.0  39e340a1-0806-41ec-828d-84651f00244e
# 691973   26.0               1.0  b9f1c63d-8006-4f39-b965-f2f46184dd4c
# 691974    7.0               1.0  e094b451-f863-44f1-a2fa-35ec90271f74
# 691975   11.0               1.0  e4abab07-a700-4160-89e8-f76b4a1ffde4
# 691976    9.0               1.0  f125003c-03c5-4479-a478-e74b89e25e55
#
#           product_id          name                     date_time
# 0          lyft_line        Shared 2018-12-16 09:30:07.890000128
# 1       lyft_premier           Lux 2018-11-27 02:00:23.676999936
# 2               lyft          Lyft 2018-11-28 01:00:22.197999872
# 3        lyft_luxsuv  Lux Black XL 2018-11-30 04:53:02.749000192
# 4          lyft_plus       Lyft XL 2018-11-29 03:49:20.223000064
# ...              ...           ...                           ...
# 691972     lyft_line        Shared 2018-12-04 04:42:56.365999872
# 691973   lyft_luxsuv  Lux Black XL 2018-12-04 04:42:56.365999872
# 691974          lyft          Lyft 2018-12-04 04:42:56.365999872
# 691975  lyft_premier           Lux 2018-12-04 04:42:56.365999872
# 691976     lyft_plus       Lyft XL 2018-12-02 16:38:03.665999872
#
# [1320 rows x 11 columns]

# %%
df2=df.loc[df.distance==1.0][0:10]    # like where condition in sql server
df2
# Out:
#       distance cab_type     time_stamp         destination  \
# 1017       1.0     Lyft  1543582376279  Financial District
# 1018       1.0     Lyft  1543345042685  Financial District
# 1019       1.0     Lyft  1543571582831  Financial District
# 1020       1.0     Lyft  1544700008953  Financial District
# 1021       1.0     Lyft  1543220463837  Financial District
# 1022       1.0     Lyft  1543311383542  Financial District
# 2952       1.0     Lyft  1545059410054    Haymarket Square
# 2953       1.0     Lyft  1543348643584    Haymarket Square
# 2954       1.0     Lyft  1543663685205    Haymarket Square
# 2955       1.0     Lyft  1544760309457    Haymarket Square
#
#                   source  price  surge_multiplier  \
# 1017    Haymarket Square    3.0               1.0
# 1018    Haymarket Square    7.0               1.0
# 1019    Haymarket Square   27.5               1.0
# 1020    Haymarket Square   10.5               1.0
# 1021    Haymarket Square   13.5               1.0
# 1022    Haymarket Square   16.5               1.0
# 2952  Financial District   27.5               1.0
# 2953  Financial District   10.5               1.0
# 2954  Financial District   10.5               1.0
# 2955  Financial District    3.0               1.0
#
#                                         id    product_id          name  \
# 1017  1b3799f4-34ec-4ead-9976-bd6a87a742b6     lyft_line        Shared
# 1018  291975a3-78ec-4852-994e-c424b7d72df7          lyft          Lyft
# 1019  5015ae80-6fc6-435c-b477-dd3e4fa199c4   lyft_luxsuv  Lux Black XL
# 1020  6c1b7367-6c00-44c1-9f95-9323e6cd79c9     lyft_plus       Lyft XL
# 1021  d06ff9ca-beb7-4190-8a30-02340d892945  lyft_premier           Lux
# 1022  fc541e1e-f5c7-47d0-8d6b-98eae58533be      lyft_lux     Lux Black
# 2952  038b0c23-6dc5-4f39-aa96-bcfb2da085d4   lyft_luxsuv  Lux Black XL
# 2953  1066daa6-d3da-47f3-83d4-172c2fa700b1  lyft_premier           Lux
# 2954  346710c5-41a0-4f73-9c2a-49bbc5dba68b     lyft_plus       Lyft XL
# 2955  75adb655-32b7-44a3-9368-dfa0ba5dff3b     lyft_line        Shared
#
#                          date_time
# 1017 2018-11-30 12:52:56.279000064
# 1018 2018-11-27 18:57:22.684999936
# 1019 2018-11-30 09:53:02.831000064
# 1020 2018-12-13 11:20:08.953000192
# 1021 2018-11-26 08:21:03.836999936
# 1022 2018-11-27 09:36:23.542000128
# 2952 2018-12-17 15:10:10.053999872
# 2953 2018-11-27 19:57:23.584000000
# 2954 2018-12-01 11:28:05.204999936
# 2955 2018-12-14 04:05:09.456999936

# %%
df3=df[(df.distance==0.44) & (df.price==5.0)]
df3
# Out:
#         distance cab_type     time_stamp    destination              source  \
# 0           0.44     Lyft  1544952607890  North Station    Haymarket Square
# 1516        0.44     Lyft  1543747082803  South Station  Financial District
# 11386       0.44     Lyft  1543847276144  South Station  Financial District
# 17218       0.44     Lyft  1543419488164  South Station  Financial District
# 24229       0.44     Lyft  1543423283646  South Station  Financial District
# ...          ...      ...            ...            ...                 ...
# 684348      0.44     Lyft  1544700307059  South Station  Financial District
# 686944      0.44     Lyft  1543282402157  South Station  Financial District
# 690266      0.44     Lyft  1543312642208  North Station    Haymarket Square
# 690319      0.44     Lyft  1544707804967  South Station  Financial District
# 691972      0.44     Lyft  1543898576366  South Station  Financial District
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1516      5.0               1.0  00e45042-50ed-4683-b213-14967ab2f873
# 11386     5.0               1.0  2d1a287f-6253-4ba3-961a-d8fbdd1bf83a
# 17218     5.0               1.0  37f2887a-b374-45c3-b6c7-9061795e1830
# 24229     5.0               1.0  1d7c8020-6d3e-41b5-956c-d83077f89066
# ...       ...               ...                                   ...
# 684348    5.0               1.0  79ce8d13-0531-472f-b277-3fdb9b7c49e7
# 686944    5.0               1.0  6313fbcf-6304-46c8-9569-78c55bde99f8
# 690266    5.0               1.0  9e9af483-b561-4fd2-85d7-145e75f9c7a2
# 690319    5.0               1.0  62e551fd-51b2-4087-bd19-7bbd30ebae54
# 691972    5.0               1.0  39e340a1-0806-41ec-828d-84651f00244e
#
#        product_id    name                     date_time
# 0       lyft_line  Shared 2018-12-16 09:30:07.890000128
# 1516    lyft_line  Shared 2018-12-02 10:38:02.803000064
# 11386   lyft_line  Shared 2018-12-03 14:27:56.144000000
# 17218   lyft_line  Shared 2018-11-28 15:38:08.164000000
# 24229   lyft_line  Shared 2018-11-28 16:41:23.645999872
# ...           ...     ...                           ...
# 684348  lyft_line  Shared 2018-12-13 11:25:07.059000064
# 686944  lyft_line  Shared 2018-11-27 01:33:22.157000192
# 690266  lyft_line  Shared 2018-11-27 09:57:22.208000000
# 690319  lyft_line  Shared 2018-12-13 13:30:04.967000064
# 691972  lyft_line  Shared 2018-12-04 04:42:56.365999872
#
# [115 rows x 11 columns]

# %%
df4=df[(df.distance==0.44) | (df.price==5.0)]
df4
# Out:
#         distance cab_type     time_stamp       destination  \
# 0           0.44     Lyft  1544952607890     North Station
# 1           0.44     Lyft  1543284023677     North Station
# 2           0.44     Lyft  1543366822198     North Station
# 3           0.44     Lyft  1543553582749     North Station
# 4           0.44     Lyft  1543463360223     North Station
# ...          ...      ...            ...               ...
# 692859      2.91     Lyft  1543319122258          Back Bay
# 692875      0.66     Lyft  1543738376113          West End
# 692961      1.12     Lyft  1543726685794  Theatre District
# 692979      3.18     Lyft  1543512478684            Fenway
# 693015      2.44     Lyft  1543513081897       Beacon Hill
#
#                          source  price  surge_multiplier  \
# 0              Haymarket Square    5.0               1.0
# 1              Haymarket Square   11.0               1.0
# 2              Haymarket Square    7.0               1.0
# 3              Haymarket Square   26.0               1.0
# 4              Haymarket Square    9.0               1.0
# ...                         ...    ...               ...
# 692859                North End    5.0               1.0
# 692875         Haymarket Square    5.0               1.0
# 692961            South Station    5.0               1.0
# 692979            North Station    5.0               1.0
# 693015  Northeastern University    5.0               1.0
#
#                                           id    product_id          name  \
# 0       424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line        Shared
# 1       4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier           Lux
# 2       981a3613-77af-4620-a42a-0c0866077d1e          lyft          Lyft
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv  Lux Black XL
# 4       e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus       Lyft XL
# ...                                      ...           ...           ...
# 692859  55f179c2-171c-426a-9ac4-566319657ec3     lyft_line        Shared
# 692875  c1a6deb7-d7e0-4e96-83e2-894a0df90eea     lyft_line        Shared
# 692961  fb736d99-b0bc-43fc-a60c-dd9b994ce0bb     lyft_line        Shared
# 692979  8342033a-1372-427f-89b7-f3dd81a8cea2     lyft_line        Shared
# 693015  e559937a-9e89-4461-a11a-85e535bac3ed     lyft_line        Shared
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 692859 2018-11-27 11:45:22.257999872
# 692875 2018-12-02 08:12:56.112999936
# 692961 2018-12-02 04:58:05.793999872
# 692979 2018-11-29 17:27:58.684000000
# 693015 2018-11-29 17:38:01.897000192
#
# [15289 rows x 11 columns]

# %%
df5=df.loc[(df.destination=="South Station") & (df.surge_multiplier==1.0) & (df.cab_type=="Lyft")][5:10]
df5
# Out:
#      distance cab_type     time_stamp    destination         source  price  \
# 49       1.76     Lyft  1543421288000  South Station  North Station   19.5
# 407      2.61     Lyft  1543594077358  South Station       Back Bay   27.5
# 408      2.61     Lyft  1543594982564  South Station       Back Bay    7.0
# 409      2.61     Lyft  1543471082637  South Station       Back Bay   10.5
# 413      2.61     Lyft  1543275914057  South Station       Back Bay   16.5
#
#      surge_multiplier                                    id product_id  \
# 49                1.0  c7a2284b-2f7b-49a8-8d5b-90e1ebe18a1f   lyft_lux
# 407               1.0  2cccac4a-57dc-4dbe-b531-bb529335e898   lyft_lux
# 408               1.0  38504f2f-300c-4e1b-bff4-4b44c3b4b842  lyft_line
# 409               1.0  3ec303ac-a8b2-4fb8-add2-c83b61c627b5       lyft
# 413               1.0  bbc3cb67-3ba6-4158-9ef6-da087068f5aa  lyft_plus
#
#           name                     date_time
# 49   Lux Black 2018-11-28 16:08:08.000000000
# 407  Lux Black 2018-11-30 16:07:57.358000128
# 408     Shared 2018-11-30 16:23:02.564000000
# 409       Lyft 2018-11-29 05:58:02.637000192
# 413    Lyft XL 2018-11-26 23:45:14.056999936

# %%
df2=df[(df.price>20) & (df.price<40)]
df2
# Out:
#         distance cab_type     time_stamp              destination  \
# 3           0.44     Lyft  1543553582749            North Station
# 9           1.08     Lyft  1543315522249  Northeastern University
# 16          1.11     Uber  1544748007961                 West End
# 23          0.72     Lyft  1544978406463         Haymarket Square
# 27          2.48     Uber  1543324882052            South Station
# ...          ...      ...            ...                      ...
# 693044      0.91     Uber  1543456028123              Beacon Hill
# 693053      3.11     Lyft  1543456028123                   Fenway
# 693058      1.61     Uber  1543456028123         Haymarket Square
# 693063      1.61     Uber  1543728484149         Haymarket Square
# 693069      1.00     Uber  1543708385534                North End
#
#                   source  price  surge_multiplier  \
# 3       Haymarket Square   26.0               1.0
# 9               Back Bay   27.5               1.0
# 16             North End   26.0               1.0
# 23         North Station   26.0               1.0
# 27           Beacon Hill   20.5               1.0
# ...                  ...    ...               ...
# 693044  Haymarket Square   26.0               1.0
# 693053  Theatre District   32.5               1.0
# 693058  Theatre District   22.0               1.0
# 693063  Theatre District   27.0               1.0
# 693069          West End   27.0               1.0
#
#                                           id  \
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 9       8612d909-98b8-4454-a093-30bd48de0cb3
# 16      91c4861c-1780-42b0-bca1-bbd64a422cc3
# 23      d0782aae-4cfa-45df-b6e4-e300b09c2563
# 27      2ca4699c-21e1-4fb4-9cc2-1d6221199d08
# ...                                      ...
# 693044  46e6b5dc-4c37-4984-8c0f-5c489d0e27e9
# 693053  ac039a91-1ca0-4210-b354-32c1e173213f
# 693058  16ccd6b9-a294-41c1-9827-0e44bd92db15
# 693063  6c1d9207-a9af-431e-a65f-3d9d205f28bf
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
#
#                                   product_id          name  \
# 3                                lyft_luxsuv  Lux Black XL
# 9                                lyft_luxsuv  Lux Black XL
# 16      6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 23                               lyft_luxsuv  Lux Black XL
# 27      6c84fd89-3f11-4782-9b50-97c468b19529         Black
# ...                                      ...           ...
# 693044  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693053                           lyft_luxsuv  Lux Black XL
# 693058  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693063  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
#
#                            date_time
# 3      2018-11-30 04:53:02.749000192
# 9      2018-11-27 10:45:22.249000192
# 16     2018-12-14 00:40:07.960999936
# 23     2018-12-16 16:40:06.463000064
# 27     2018-11-27 13:21:22.052000000
# ...                              ...
# 693044 2018-11-29 01:47:08.122999808
# 693053 2018-11-29 01:47:08.122999808
# 693058 2018-11-29 01:47:08.122999808
# 693063 2018-12-02 05:28:04.148999936
# 693069 2018-12-01 23:53:05.533999872
#
# [180170 rows x 11 columns]

# %%
df["name"].value_counts()
# Out:
# UberXL          55096
# WAV             55096
# Black SUV       55096
# Black           55095
# Taxi            55095
# UberX           55094
# UberPool        55091
# Lux             51235
# Lyft            51235
# Lux Black XL    51235
# Lyft XL         51235
# Lux Black       51235
# Shared          51233
# Name: name, dtype: int64

# %%
df.sort_values(by=['distance'],ascending=False)
# Out:
#         distance cab_type     time_stamp         destination  \
# 658723      7.86     Uber  1545063010990  Financial District
# 658724      7.86     Uber  1545063010990  Financial District
# 658725      7.86     Uber  1544850306199  Financial District
# 658726      7.86     Uber  1544850306199  Financial District
# 658727      7.86     Uber  1544850306199  Financial District
# ...          ...      ...            ...                 ...
# 172933      0.02     Uber  1544397507859       South Station
# 172932      0.02     Uber  1544397507859       South Station
# 283073      0.02     Uber  1544885412017    Theatre District
# 283074      0.02     Uber  1544934313639    Theatre District
# 283071      0.02     Uber  1544885412017    Theatre District
#
#                          source  price  surge_multiplier  \
# 658723  Northeastern University   17.5               1.0
# 658724  Northeastern University   36.0               1.0
# 658725  Northeastern University   17.5               1.0
# 658726  Northeastern University   13.5               1.0
# 658727  Northeastern University    NaN               1.0
# ...                         ...    ...               ...
# 172933         Theatre District    NaN               1.0
# 172932         Theatre District   27.5               1.0
# 283073            South Station    6.5               1.0
# 283074            South Station    6.5               1.0
# 283071            South Station    NaN               1.0
#
#                                           id  \
# 658723  03832272-f604-4c54-845a-b55387703959
# 658724  15582e0b-da46-439e-abfa-a6af0deead98
# 658725  2596d91f-64fd-4235-b401-f48997b4b38b
# 658726  5bab99ba-9e97-423b-8129-41999254ae05
# 658727  8108cdde-7589-4569-8031-fb0e75e9f925
# ...                                      ...
# 172933  182e52da-7112-4d3e-b3c8-d112b3cee710
# 172932  0d3a073e-94c6-4b77-92ef-d2eb9eaac346
# 283073  dd9f8988-4428-418c-ad99-fffc024c51ca
# 283074  de13d5c0-799c-4b15-b938-d954513ad934
# 283071  cee0e184-f4b7-472e-b3c1-7b997b77847c
#
#                                   product_id       name  \
# 658723  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 658724  6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 658725  9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV
# 658726  997acbb5-e102-41e1-b155-9df7de0a73f2   UberPool
# 658727  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# ...                                      ...        ...
# 172933  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 172932  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 283073  9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV
# 283074  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 283071  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
#
#                            date_time
# 658723 2018-12-17 16:10:10.990000128
# 658724 2018-12-17 16:10:10.990000128
# 658725 2018-12-15 05:05:06.198999808
# 658726 2018-12-15 05:05:06.198999808
# 658727 2018-12-15 05:05:06.198999808
# ...                              ...
# 172933 2018-12-09 23:18:27.859000064
# 172932 2018-12-09 23:18:27.859000064
# 283073 2018-12-15 14:50:12.016999936
# 283074 2018-12-16 04:25:13.639000064
# 283071 2018-12-15 14:50:12.016999936
#
# [693071 rows x 11 columns]

# %%
df.sort_values(by=['price'])
# Out:
#         distance cab_type     time_stamp         destination  \
# 55268       1.41     Lyft  1543457467967         Beacon Hill
# 331426      0.66     Lyft  1544846408733  Financial District
# 592088      0.44     Lyft  1543409048069       South Station
# 525697      1.54     Lyft  1543428668589            Back Bay
# 40379       2.09     Lyft  1543657978614       South Station
# ...          ...      ...            ...                 ...
# 693025      2.50     Uber  1544886913192         Beacon Hill
# 693047      0.91     Uber  1543456028123         Beacon Hill
# 693049      1.79     Uber  1543456028123         Beacon Hill
# 693060      1.61     Uber  1543728484149    Haymarket Square
# 693068      1.00     Uber  1543708385534           North End
#
#                     source  price  surge_multiplier  \
# 55268     Haymarket Square    2.5               1.0
# 331426       South Station    2.5               1.0
# 592088  Financial District    2.5               1.0
# 525697   Boston University    2.5               1.0
# 40379        North Station    2.5               1.0
# ...                    ...    ...               ...
# 693025       South Station    NaN               1.0
# 693047    Haymarket Square    NaN               1.0
# 693049           North End    NaN               1.0
# 693060    Theatre District    NaN               1.0
# 693068            West End    NaN               1.0
#
#                                           id  \
# 55268   e00851d7-3212-4ac1-b21e-4b731e2f5328
# 331426  7f883f8c-5be7-4fbd-814a-a1e1a5d36f2d
# 592088  08032b47-706f-409b-a32d-32ef1afdb934
# 525697  368d8b32-b838-4f24-953d-ef811b0f49f7
# 40379   36b64631-c3a7-4316-8760-b00a720aef72
# ...                                      ...
# 693025  70ad9983-92dd-4cdf-af16-732e7e9ee9d0
# 693047  84e05ef0-781a-4bd5-a593-bbbf659d4ba0
# 693049  885ef635-299e-45cf-8052-c45a39e9822a
# 693060  50a7b6be-ed2a-4a11-8d36-73bd977ad66a
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f
#
#                                   product_id    name  \
# 55268                              lyft_line  Shared
# 331426                             lyft_line  Shared
# 592088                             lyft_line  Shared
# 525697                             lyft_line  Shared
# 40379                              lyft_line  Shared
# ...                                      ...     ...
# 693025  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    Taxi
# 693047  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    Taxi
# 693049  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    Taxi
# 693060  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    Taxi
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    Taxi
#
#                            date_time
# 55268  2018-11-29 02:11:07.967000064
# 331426 2018-12-15 04:00:08.732999936
# 592088 2018-11-28 12:44:08.068999936
# 525697 2018-11-28 18:11:08.588999936
# 40379  2018-12-01 09:52:58.614000128
# ...                              ...
# 693025 2018-12-15 15:15:13.192000000
# 693047 2018-11-29 01:47:08.122999808
# 693049 2018-11-29 01:47:08.122999808
# 693060 2018-12-02 05:28:04.148999936
# 693068 2018-12-01 23:53:05.533999872
#
# [693071 rows x 11 columns]

# %%
df.sort_values(by=['price'],ascending=False)
# Out:
#         distance cab_type     time_stamp         destination  \
# 597071      4.43     Lyft  1543714082123              Fenway
# 280566      5.39     Lyft  1543356201754   Boston University
# 560058      4.37     Lyft  1544940005181  Financial District
# 537453      4.39     Lyft  1544758807486  Financial District
# 28083       3.89     Lyft  1543441295635  Financial District
# ...          ...      ...            ...                 ...
# 693025      2.50     Uber  1544886913192         Beacon Hill
# 693047      0.91     Uber  1543456028123         Beacon Hill
# 693049      1.79     Uber  1543456028123         Beacon Hill
# 693060      1.61     Uber  1543728484149    Haymarket Square
# 693068      1.00     Uber  1543708385534           North End
#
#                     source  price  surge_multiplier  \
# 597071  Financial District   97.5               2.0
# 280566  Financial District   92.0               2.0
# 560058   Boston University   92.0               2.0
# 537453   Boston University   92.0               2.0
# 28083               Fenway   92.0               2.0
# ...                    ...    ...               ...
# 693025       South Station    NaN               1.0
# 693047    Haymarket Square    NaN               1.0
# 693049           North End    NaN               1.0
# 693060    Theatre District    NaN               1.0
# 693068            West End    NaN               1.0
#
#                                           id  \
# 597071  ba1593a1-e4fd-4c7a-a011-e2d4fccbf081
# 280566  fe9f56b5-e54a-48b4-b702-4e625adcf0ab
# 560058  71ad1473-ebc6-4b98-80c6-0f56046af3e2
# 537453  fa0c51a4-acc0-4c49-8244-561e9ad945e3
# 28083   edb9ba13-b129-487f-be93-2e3abdd700a3
# ...                                      ...
# 693025  70ad9983-92dd-4cdf-af16-732e7e9ee9d0
# 693047  84e05ef0-781a-4bd5-a593-bbbf659d4ba0
# 693049  885ef635-299e-45cf-8052-c45a39e9822a
# 693060  50a7b6be-ed2a-4a11-8d36-73bd977ad66a
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f
#
#                                   product_id          name  \
# 597071                           lyft_luxsuv  Lux Black XL
# 280566                           lyft_luxsuv  Lux Black XL
# 560058                           lyft_luxsuv  Lux Black XL
# 537453                           lyft_luxsuv  Lux Black XL
# 28083                            lyft_luxsuv  Lux Black XL
# ...                                      ...           ...
# 693025  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693047  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693049  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693060  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
#
#                            date_time
# 597071 2018-12-02 01:28:02.122999808
# 280566 2018-11-27 22:03:21.753999872
# 560058 2018-12-16 06:00:05.180999936
# 537453 2018-12-14 03:40:07.486000128
# 28083  2018-11-28 21:41:35.635000064
# ...                              ...
# 693025 2018-12-15 15:15:13.192000000
# 693047 2018-11-29 01:47:08.122999808
# 693049 2018-11-29 01:47:08.122999808
# 693060 2018-12-02 05:28:04.148999936
# 693068 2018-12-01 23:53:05.533999872
#
# [693071 rows x 11 columns]

# %%
df.sort_values(by=['distance','price'],ascending=False)
# Out:
#         distance cab_type     time_stamp         destination  \
# 658728      7.86     Uber  1544850306199  Financial District
# 658724      7.86     Uber  1545063010990  Financial District
# 658729      7.86     Uber  1544850306199  Financial District
# 658723      7.86     Uber  1545063010990  Financial District
# 658725      7.86     Uber  1544850306199  Financial District
# ...          ...      ...            ...                 ...
# 415255      0.02     Uber  1543400587892       South Station
# 440547      0.02     Uber  1543319662229    Theatre District
# 514757      0.02     Uber  1543882984574       South Station
# 578083      0.02     Uber  1543269370145       South Station
# 598125      0.02     Uber  1543233731475    Theatre District
#
#                          source  price  surge_multiplier  \
# 658728  Northeastern University   53.0               1.0
# 658724  Northeastern University   36.0               1.0
# 658729  Northeastern University   29.5               1.0
# 658723  Northeastern University   17.5               1.0
# 658725  Northeastern University   17.5               1.0
# ...                         ...    ...               ...
# 415255         Theatre District    NaN               1.0
# 440547            South Station    NaN               1.0
# 514757         Theatre District    NaN               1.0
# 578083         Theatre District    NaN               1.0
# 598125            South Station    NaN               1.0
#
#                                           id  \
# 658728  f40aa84e-fe70-4ef7-9860-9315fb8cd63f
# 658724  15582e0b-da46-439e-abfa-a6af0deead98
# 658729  f70c929c-9476-42ec-8776-b9ff48e575cc
# 658723  03832272-f604-4c54-845a-b55387703959
# 658725  2596d91f-64fd-4235-b401-f48997b4b38b
# ...                                      ...
# 415255  5f1f11f4-d639-4183-95da-56ed0951f653
# 440547  b5c4e989-5983-4328-98b4-20e7d7ca95a2
# 514757  d18997a8-1c53-4f37-add1-1259817ad0a0
# 578083  cebe0811-97dd-4d3c-a9a6-af8d8a1048d8
# 598125  8f88365e-4e00-4d77-bd6d-8233195390ba
#
#                                   product_id       name  \
# 658728  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 658724  6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 658729  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL
# 658723  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 658725  9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV
# ...                                      ...        ...
# 415255  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 440547  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 514757  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 578083  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 598125  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
#
#                            date_time
# 658728 2018-12-15 05:05:06.198999808
# 658724 2018-12-17 16:10:10.990000128
# 658729 2018-12-15 05:05:06.198999808
# 658723 2018-12-17 16:10:10.990000128
# 658725 2018-12-15 05:05:06.198999808
# ...                              ...
# 415255 2018-11-28 10:23:07.892000000
# 440547 2018-11-27 11:54:22.229000192
# 514757 2018-12-04 00:23:04.573999872
# 578083 2018-11-26 21:56:10.144999936
# 598125 2018-11-26 12:02:11.474999808
#
# [693071 rows x 11 columns]

# %%
df.sort_values(by=['price','distance'],ascending=False)
# Out:
#         distance cab_type     time_stamp        destination  \
# 597071      4.43     Lyft  1543714082123             Fenway
# 271719      5.39     Lyft  1543453328714  Boston University
# 280566      5.39     Lyft  1543356201754  Boston University
# 440000      5.37     Lyft  1543694879927  Boston University
# 301021      5.36     Lyft  1545090313982  Boston University
# ...          ...      ...            ...                ...
# 415255      0.02     Uber  1543400587892      South Station
# 440547      0.02     Uber  1543319662229   Theatre District
# 514757      0.02     Uber  1543882984574      South Station
# 578083      0.02     Uber  1543269370145      South Station
# 598125      0.02     Uber  1543233731475   Theatre District
#
#                     source  price  surge_multiplier  \
# 597071  Financial District   97.5               2.0
# 271719  Financial District   92.0               2.0
# 280566  Financial District   92.0               2.0
# 440000  Financial District   92.0               2.0
# 301021  Financial District   92.0               2.0
# ...                    ...    ...               ...
# 415255    Theatre District    NaN               1.0
# 440547       South Station    NaN               1.0
# 514757    Theatre District    NaN               1.0
# 578083    Theatre District    NaN               1.0
# 598125       South Station    NaN               1.0
#
#                                           id  \
# 597071  ba1593a1-e4fd-4c7a-a011-e2d4fccbf081
# 271719  6f17623a-f97c-4379-9188-4f3e07d1c48e
# 280566  fe9f56b5-e54a-48b4-b702-4e625adcf0ab
# 440000  2a3f4de9-7a24-4580-8079-a7953a1431e3
# 301021  16373de7-5ef0-45a7-86d8-842bd12780e9
# ...                                      ...
# 415255  5f1f11f4-d639-4183-95da-56ed0951f653
# 440547  b5c4e989-5983-4328-98b4-20e7d7ca95a2
# 514757  d18997a8-1c53-4f37-add1-1259817ad0a0
# 578083  cebe0811-97dd-4d3c-a9a6-af8d8a1048d8
# 598125  8f88365e-4e00-4d77-bd6d-8233195390ba
#
#                                   product_id          name  \
# 597071                           lyft_luxsuv  Lux Black XL
# 271719                           lyft_luxsuv  Lux Black XL
# 280566                           lyft_luxsuv  Lux Black XL
# 440000                           lyft_luxsuv  Lux Black XL
# 301021                           lyft_luxsuv  Lux Black XL
# ...                                      ...           ...
# 415255  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 440547  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 514757  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 578083  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 598125  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
#
#                            date_time
# 597071 2018-12-02 01:28:02.122999808
# 271719 2018-11-29 01:02:08.713999872
# 280566 2018-11-27 22:03:21.753999872
# 440000 2018-12-01 20:07:59.927000064
# 301021 2018-12-17 23:45:13.982000128
# ...                              ...
# 415255 2018-11-28 10:23:07.892000000
# 440547 2018-11-27 11:54:22.229000192
# 514757 2018-12-04 00:23:04.573999872
# 578083 2018-11-26 21:56:10.144999936
# 598125 2018-11-26 12:02:11.474999808
#
# [693071 rows x 11 columns]

# %%
df_new=df.loc[~df.price.isnull()]
df_new
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693065      1.00     Uber  1543708385534      North End          West End
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693065    9.5               1.0  353e6566-b272-479e-a9c6-98bd6cb23f25
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693065  9a0e7b09-b92b-4c41-9779-2ad22b4d779d           WAV
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 693065 2018-12-01 23:53:05.533999872
# 693066 2018-12-01 23:53:05.533999872
# 693067 2018-12-01 23:53:05.533999872
# 693069 2018-12-01 23:53:05.533999872
# 693070 2018-12-01 23:53:05.533999872
#
# [637976 rows x 11 columns]

# %%
df_new.isnull().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# date_time           0
# dtype: int64

# %%
df7 = df[(df.source=="West End") & (df.destination=="North End") & (df.price >= 10)]
df7
df7.count()
# Out:
# distance            5030
# cab_type            5030
# time_stamp          5030
# destination         5030
# source              5030
# price               5030
# surge_multiplier    5030
# id                  5030
# product_id          5030
# name                5030
# date_time           5030
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df.distance)
# Out:
# (array([ 67786., 194738., 129082., 187615.,  63532.,  35996.,   6954.,
#           4856.,    412.,   2100.]),
#  array([0.02 , 0.804, 1.588, 2.372, 3.156, 3.94 , 4.724, 5.508, 6.292,
#         7.076, 7.86 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.price)
# Out:
# (array([2.69805e+05, 1.84912e+05, 1.30154e+05, 4.38570e+04, 7.21500e+03,
#         1.44000e+03, 4.08000e+02, 9.00000e+01, 7.30000e+01, 2.20000e+01]),
#  array([ 2.5, 12. , 21.5, 31. , 40.5, 50. , 59.5, 69. , 78.5, 88. , 97.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.price)
# Out:
# (array([2.69805e+05, 1.84912e+05, 1.30154e+05, 4.38570e+04, 7.21500e+03,
#         1.44000e+03, 4.08000e+02, 9.00000e+01, 7.30000e+01, 2.20000e+01]),
#  array([ 2.5, 12. , 21.5, 31. , 40.5, 50. , 59.5, 69. , 78.5, 88. , 97.5]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Observations
# 1. the highest number of trips in range between 0$ and 10$ having more than 2.5 lacs count
# 2. the increasing in price the number of trips are decreasing

# %%
df.price
# Out:
# 0          5.0
# 1         11.0
# 2          7.0
# 3         26.0
# 4          9.0
#           ...
# 693066    13.0
# 693067     9.5
# 693068     NaN
# 693069    27.0
# 693070    10.0
# Name: price, Length: 693071, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")
sns.FacetGrid(df, hue="cab_type" ,size=5).map(sns.distplot, "distance").add_legend()
plt.show()

# %%
sns.FacetGrid(df,size=5).map(sns.distplot, "price").add_legend()
plt.show()

# %% [markdown]
# # observations
# 1. for the lowest price public preference is Uber

# %%
# Syntax
# sns.FacetGrid(df, hue="cab_type" ,size=5).map(sns.distplot, "price").add_legend()
# facetgrid is a function by which we can make distribution slots.
# df is a dataframe

# %% [markdown]
# # questions to solve
# 1. what is the percentage distribution of lyft and uber

# %%
perct_dist = df.cab_type.value_counts()
perct_dist
# Out:
# Uber    385663
# Lyft    307408
# Name: cab_type, dtype: int64

# %%
index = perct_dist.index
sizes = perct_dist.values
print(index)
print(sizes)
# Out:
# Index(['Uber', 'Lyft'], dtype='object')
# [385663 307408]

# %%
plt.pie(sizes, labels=index, autopct='%1.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca2b77cd0>,
#   <matplotlib.patches.Wedge at 0x1bca2b5b6a0>],
#  [Text(-0.19407413012528127, 1.0827443059264341, 'Uber'),
#   Text(0.19407413012528138, -1.0827443059264341, 'Lyft')],
#  [Text(-0.10585861643197159, 0.5905878032326004, '55.65%'),
#   Text(0.10585861643197166, -0.5905878032326004, '44.35%')])

# %%
perct_dist_src = df.source.value_counts()
perct_dist_src
# Out:
# Financial District         58857
# Theatre District           57813
# Back Bay                   57792
# Boston University          57764
# North End                  57763
# Fenway                     57757
# Northeastern University    57756
# South Station              57750
# Haymarket Square           57736
# West End                   57562
# Beacon Hill                57403
# North Station              57118
# Name: source, dtype: int64

# %%
index1=perct_dist_src.index
sizes1=perct_dist_src.values
print(index1)
print(sizes1)
# Out:
# Index(['Financial District', 'Theatre District', 'Back Bay',
#        'Boston University', 'North End', 'Fenway', 'Northeastern University',
#        'South Station', 'Haymarket Square', 'West End', 'Beacon Hill',
#        'North Station'],
#       dtype='object')
# [58857 57813 57792 57764 57763 57757 57756 57750 57736 57562 57403 57118]

# %%
plt.pie(sizes1, labels=index1, autopct='%1.1f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca867cf40>,
#   <matplotlib.patches.Wedge at 0x1bca2cdd910>,
#   <matplotlib.patches.Wedge at 0x1bca2caf2e0>,
#   <matplotlib.patches.Wedge at 0x1bca2cafc70>,
#   <matplotlib.patches.Wedge at 0x1bca2cd3640>,
#   <matplotlib.patches.Wedge at 0x1bca2cd3fd0>,
#   <matplotlib.patches.Wedge at 0x1bca2cc69a0>,
#   <matplotlib.patches.Wedge at 0x1bcaf9a9370>,
#   <matplotlib.patches.Wedge at 0x1bcaf9a9d00>,
#   <matplotlib.patches.Wedge at 0x1bcaf99b6d0>,
#   <matplotlib.patches.Wedge at 0x1bca867cf10>,
#   <matplotlib.patches.Wedge at 0x1bcaf98ea00>],
#  [Text(1.061084220434575, 0.2900004778353825, 'Financial District'),
#   Text(0.7698112834347768, 0.7857420619366778, 'Theatre District'),
#   Text(0.27335516757588646, 1.065493759887668, 'Back Bay'),
#   Text(-0.29622643996211256, 1.0593629671965001, 'Boston University'),
#   Text(-0.7862739854039774, 0.7692679766355454, 'North End'),
#   Text(-1.0655773363232253, 0.273029193153956, 'Fenway'),
#   Text(-1.0593300742229077, -0.2963440464171485, 'Northeastern University'),
#   Text(-0.7692555169829924, -0.7862861753784237, 'South Station'),
#   Text(-0.2731764958563372, -1.065539582611389, 'Haymarket Square'),
#   Text(0.2951650397987332, -1.0596591901553123, 'West End'),
#   Text(0.7835387144211516, -0.7720538083600451, 'Beacon Hill'),
#   Text(1.0633371894094954, -0.28162745182015775, 'North Station')],
#  [Text(0.5787732111461318, 0.15818207881929952, '8.5%'),
#   Text(0.4198970636916964, 0.4285865792381879, '8.3%'),
#   Text(0.14910281867775624, 0.5811784144841824, '8.3%'),
#   Text(-0.1615780581611523, 0.5778343457435455, '8.3%'),
#   Text(-0.42887671931126037, 0.41960071452847925, '8.3%'),
#   Text(-0.5812240016308501, 0.14892501444761236, '8.3%'),
#   Text(-0.577816404121586, -0.16164220713662644, '8.3%'),
#   Text(-0.41959391835435944, -0.42888336838823105, '8.3%'),
#   Text(-0.14900536137618392, -0.5812034086971212, '8.3%'),
#   Text(0.1609991126174908, -0.5779959219028976, '8.3%'),
#   Text(0.42738475332062814, -0.4211202591054791, '8.3%'),
#   Text(0.5800021033142702, -0.153614973720086, '8.2%')])

# %%
perct_dist_dest=df.destination.value_counts()
perct_dist_dest
# Out:
# Financial District         58851
# Theatre District           57798
# Back Bay                   57780
# Haymarket Square           57764
# Boston University          57764
# Fenway                     57757
# North End                  57756
# Northeastern University    57755
# South Station              57749
# West End                   57575
# Beacon Hill                57403
# North Station              57119
# Name: destination, dtype: int64

# %%
index2=perct_dist_dest.index
sizes2=perct_dist_dest.values

# %%
plt.pie(sizes2, labels=index2, autopct='%1.2f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca2d29be0>,
#   <matplotlib.patches.Wedge at 0x1bca2d655b0>,
#   <matplotlib.patches.Wedge at 0x1bca2d65f40>,
#   <matplotlib.patches.Wedge at 0x1bca2d73910>,
#   <matplotlib.patches.Wedge at 0x1bca2d812e0>,
#   <matplotlib.patches.Wedge at 0x1bca2d81c70>,
#   <matplotlib.patches.Wedge at 0x1bca2d8f640>,
#   <matplotlib.patches.Wedge at 0x1bca2d8ffd0>,
#   <matplotlib.patches.Wedge at 0x1bca2d9d9a0>,
#   <matplotlib.patches.Wedge at 0x1bca2dab370>,
#   <matplotlib.patches.Wedge at 0x1bca2d29bb0>,
#   <matplotlib.patches.Wedge at 0x1bca2db86a0>],
#  [Text(1.0610921076412452, 0.28997161775156627, 'Financial District'),
#   Text(0.7699074474510679, 0.7856478360941253, 'Theatre District'),
#   Text(0.273615953632954, 1.0654268205360373, 'Back Bay'),
#   Text(-0.29590953153540206, 1.059451532230946, 'Haymarket Square'),
#   Text(-0.7860473275644332, 0.7694995768867016, 'Boston University'),
#   Text(-1.065498097827655, 0.2733382584375066, 'Fenway'),
#   Text(-1.0594159859376344, -0.2960367692361715, 'North End'),
#   Text(-0.7694657408439834, -0.7860804498697445, 'Northeastern University'),
#   Text(-0.2733744957839597, -1.0654888009992718, 'South Station'),
#   Text(0.29509301087561185, -1.059679250968125, 'West End'),
#   Text(0.7835317388968651, -0.7720608875867596, 'Beacon Hill'),
#   Text(1.0633359237412365, -0.2816322305443241, 'North Station')],
#  [Text(0.578777513258861, 0.15816633695539975, '8.49%'),
#   Text(0.4199495167914915, 0.42853518332406826, '8.34%'),
#   Text(0.1492450656179749, 0.5811419021105657, '8.34%'),
#   Text(-0.1614051990193102, 0.5778826539441523, '8.33%'),
#   Text(-0.4287530877624181, 0.4197270419382008, '8.33%'),
#   Text(-0.5811807806332663, 0.1490935955113672, '8.33%'),
#   Text(-0.5778632650568915, -0.1614746014015481, '8.33%'),
#   Text(-0.41970858591490007, -0.428771154474406, '8.33%'),
#   Text(-0.1491133613367053, -0.5811757096359664, '8.33%'),
#   Text(0.16095982411397008, -0.5780068641644317, '8.31%'),
#   Text(0.4273809484891991, -0.4211241205018688, '8.28%'),
#   Text(0.5800014129497653, -0.15361758029690403, '8.24%')])

# %%
new_df = df[["source","destination"]]
new_df
# Out:
#                   source    destination
# 0       Haymarket Square  North Station
# 1       Haymarket Square  North Station
# 2       Haymarket Square  North Station
# 3       Haymarket Square  North Station
# 4       Haymarket Square  North Station
# ...                  ...            ...
# 693066          West End      North End
# 693067          West End      North End
# 693068          West End      North End
# 693069          West End      North End
# 693070          West End      North End
#
# [693071 rows x 2 columns]

# %%
new_df["std"] =df.source + "-" + df.destination    # adding new column std
new_df
# Out:
#                   source    destination                             std
# 0       Haymarket Square  North Station  Haymarket Square-North Station
# 1       Haymarket Square  North Station  Haymarket Square-North Station
# 2       Haymarket Square  North Station  Haymarket Square-North Station
# 3       Haymarket Square  North Station  Haymarket Square-North Station
# 4       Haymarket Square  North Station  Haymarket Square-North Station
# ...                  ...            ...                             ...
# 693066          West End      North End              West End-North End
# 693067          West End      North End              West End-North End
# 693068          West End      North End              West End-North End
# 693069          West End      North End              West End-North End
# 693070          West End      North End              West End-North End
#
# [693071 rows x 3 columns]

# %%
std_value=new_df["std"].value_counts()
std_value
# Out:
# Financial District-South Station    10352
# South Station-Financial District    10352
# Back Bay-North End                  10225
# North End-Back Bay                  10225
# West End-Fenway                     10165
#                                     ...
# West End-North End                   9206
# Haymarket Square-West End            9156
# West End-Haymarket Square            9156
# South Station-North Station          9153
# North Station-South Station          9146
# Name: std, Length: 72, dtype: int64

# %%
top_10 = std_value [:10]
top_10
# Out:
# Financial District-South Station       10352
# South Station-Financial District       10352
# Back Bay-North End                     10225
# North End-Back Bay                     10225
# West End-Fenway                        10165
# Fenway-West End                        10165
# Haymarket Square-Financial District    10134
# Financial District-Haymarket Square    10133
# Beacon Hill-North End                  10039
# North End-Beacon Hill                  10039
# Name: std, dtype: int64

# %%
sns.barplot(top_10.values, top_10.index)
# Out:
# <AxesSubplot:>

# %%
sm=df.surge_multiplier.value_counts()
sm
# Out:
# 1.00    672096
# 1.25     11085
# 1.50      5065
# 1.75      2420
# 2.00      2239
# 2.50       154
# 3.00        12
# Name: surge_multiplier, dtype: int64

# %%
plt.pie(sm.values, labels=sm.index, autopct='%1.2f%%') # plt.pie(size,labels,autopct='%1.1%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca2f9ba90>,
#   <matplotlib.patches.Wedge at 0x1bca2e28220>,
#   <matplotlib.patches.Wedge at 0x1bca2e28940>,
#   <matplotlib.patches.Wedge at 0x1bca2e370a0>,
#   <matplotlib.patches.Wedge at 0x1bca2e377c0>,
#   <matplotlib.patches.Wedge at 0x1bca2e37ee0>,
#   <matplotlib.patches.Wedge at 0x1bca2e44640>],
#  [Text(-1.0950319797796475, 0.10442683208766762, '1.0'),
#   Text(1.0892519298931558, -0.153395675375924, '1.25'),
#   Text(1.0975539499436187, -0.07331662132941448, '1.5'),
#   Text(1.099409333496767, -0.036043271496837434, '1.75'),
#   Text(1.0999253036122802, -0.012818988783568377, '2.0'),
#   Text(1.0999996420258382, -0.0008874362107320797, '2.5'),
#   Text(1.0999999983779831, -5.973639794567116e-05, '3.0')],
#  [Text(-0.5972901707888986, 0.05696009022963687, '96.97%'),
#   Text(0.5941374163053577, -0.08367036838686762, '1.60%'),
#   Text(0.5986657908783374, -0.03999088436149881, '0.73%'),
#   Text(0.5996778182709638, -0.019659966271002232, '0.35%'),
#   Text(0.5999592565157892, -0.006992175700128204, '0.32%'),
#   Text(0.5999998047413662, -0.0004840561149447707, '0.02%'),
#   Text(0.5999999991152635, -3.25834897885479e-05, '0.00%')])

# %%
nm=df.name.value_counts()
nm
# Out:
# UberXL          55096
# WAV             55096
# Black SUV       55096
# Black           55095
# Taxi            55095
# UberX           55094
# UberPool        55091
# Lux             51235
# Lyft            51235
# Lux Black XL    51235
# Lyft XL         51235
# Lux Black       51235
# Shared          51233
# Name: name, dtype: int64

# %%
plt.pie(nm.values, labels=nm.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca2e887f0>,
#   <matplotlib.patches.Wedge at 0x1bca2e88f10>,
#   <matplotlib.patches.Wedge at 0x1bca2e98670>,
#   <matplotlib.patches.Wedge at 0x1bca2e98d90>,
#   <matplotlib.patches.Wedge at 0x1bca2ea64f0>,
#   <matplotlib.patches.Wedge at 0x1bca2ea6c10>,
#   <matplotlib.patches.Wedge at 0x1bca2eb5370>,
#   <matplotlib.patches.Wedge at 0x1bca2eb5a90>,
#   <matplotlib.patches.Wedge at 0x1bca2ec01f0>,
#   <matplotlib.patches.Wedge at 0x1bca2ec0910>,
#   <matplotlib.patches.Wedge at 0x1bca2e887c0>,
#   <matplotlib.patches.Wedge at 0x1bca2ecf760>,
#   <matplotlib.patches.Wedge at 0x1bca2ecfe80>],
#  [Text(1.0658737458223562, 0.2718697444855159, 'UberXL'),
#   Text(0.8054370696324703, 0.7491803033061263, 'WAV'),
#   Text(0.3481990798560852, 1.043435384097825, 'Black SUV'),
#   Text(-0.19411333632992658, 1.0827372777635695, 'Black'),
#   Text(-0.6889928686250644, 0.8574898407467023, 'Taxi'),
#   Text(-1.0155272255770602, 0.4227344960040036, 'UberX'),
#   Text(-1.093941924591129, -0.11528688399751628, 'UberPool'),
#   Text(-0.91589112209238, -0.6092154401132339, 'Lux'),
#   Text(-0.5459518680590152, -0.9549536940411676, 'Lyft'),
#   Text(-0.0603294776359242, -1.0983443695527266, 'Lux Black XL'),
#   Text(0.4380762799629032, -1.009004050008653, 'Lyft XL'),
#   Text(0.8436569351873681, -0.7058632840077866, 'Lux Black'),
#   Text(1.070470667475576, -0.25316506487743345, 'Shared')],
#  [Text(0.5813856795394668, 0.14829258790119046, '7.9%'),
#   Text(0.43932931070862014, 0.40864380180334153, '7.9%'),
#   Text(0.18992677083059192, 0.5691465731442681, '7.9%'),
#   Text(-0.1058800016345054, 0.5905839696892197, '7.9%'),
#   Text(-0.3758142919773078, 0.467721731316383, '7.9%'),
#   Text(-0.5539239412238509, 0.23058245236582012, '7.9%'),
#   Text(-0.5966955952315248, -0.06288375490773615, '7.9%'),
#   Text(-0.4995769756867527, -0.3322993309708548, '7.4%'),
#   Text(-0.29779192803219007, -0.5208838331133641, '7.4%'),
#   Text(-0.0329069878014132, -0.5990969288469418, '7.4%'),
#   Text(0.23895069816158354, -0.5503658454592653, '7.4%'),
#   Text(0.46017651010220073, -0.3850163367315199, '7.4%'),
#   Text(0.5838930913503141, -0.13809003538769096, '7.4%')])

# %%
sns.barplot (nm.values,nm.index)
# Out:
# <AxesSubplot:>

# %%
df.sort_values(by=['price'],ascending=False)
# Out:
#         distance cab_type     time_stamp         destination  \
# 597071      4.43     Lyft  1543714082123              Fenway
# 280566      5.39     Lyft  1543356201754   Boston University
# 560058      4.37     Lyft  1544940005181  Financial District
# 537453      4.39     Lyft  1544758807486  Financial District
# 28083       3.89     Lyft  1543441295635  Financial District
# ...          ...      ...            ...                 ...
# 693025      2.50     Uber  1544886913192         Beacon Hill
# 693047      0.91     Uber  1543456028123         Beacon Hill
# 693049      1.79     Uber  1543456028123         Beacon Hill
# 693060      1.61     Uber  1543728484149    Haymarket Square
# 693068      1.00     Uber  1543708385534           North End
#
#                     source  price  surge_multiplier  \
# 597071  Financial District   97.5               2.0
# 280566  Financial District   92.0               2.0
# 560058   Boston University   92.0               2.0
# 537453   Boston University   92.0               2.0
# 28083               Fenway   92.0               2.0
# ...                    ...    ...               ...
# 693025       South Station    NaN               1.0
# 693047    Haymarket Square    NaN               1.0
# 693049           North End    NaN               1.0
# 693060    Theatre District    NaN               1.0
# 693068            West End    NaN               1.0
#
#                                           id  \
# 597071  ba1593a1-e4fd-4c7a-a011-e2d4fccbf081
# 280566  fe9f56b5-e54a-48b4-b702-4e625adcf0ab
# 560058  71ad1473-ebc6-4b98-80c6-0f56046af3e2
# 537453  fa0c51a4-acc0-4c49-8244-561e9ad945e3
# 28083   edb9ba13-b129-487f-be93-2e3abdd700a3
# ...                                      ...
# 693025  70ad9983-92dd-4cdf-af16-732e7e9ee9d0
# 693047  84e05ef0-781a-4bd5-a593-bbbf659d4ba0
# 693049  885ef635-299e-45cf-8052-c45a39e9822a
# 693060  50a7b6be-ed2a-4a11-8d36-73bd977ad66a
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f
#
#                                   product_id          name  \
# 597071                           lyft_luxsuv  Lux Black XL
# 280566                           lyft_luxsuv  Lux Black XL
# 560058                           lyft_luxsuv  Lux Black XL
# 537453                           lyft_luxsuv  Lux Black XL
# 28083                            lyft_luxsuv  Lux Black XL
# ...                                      ...           ...
# 693025  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693047  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693049  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693060  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693068  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
#
#                            date_time
# 597071 2018-12-02 01:28:02.122999808
# 280566 2018-11-27 22:03:21.753999872
# 560058 2018-12-16 06:00:05.180999936
# 537453 2018-12-14 03:40:07.486000128
# 28083  2018-11-28 21:41:35.635000064
# ...                              ...
# 693025 2018-12-15 15:15:13.192000000
# 693047 2018-11-29 01:47:08.122999808
# 693049 2018-11-29 01:47:08.122999808
# 693060 2018-12-02 05:28:04.148999936
# 693068 2018-12-01 23:53:05.533999872
#
# [693071 rows x 11 columns]

# %%
pc=df.price.value_counts()
pc
# Out:
# 7.00     52314
# 16.50    44351
# 10.50    40590
# 13.50    33707
# 9.00     30884
#          ...
# 89.50        1
# 81.50        1
# 64.50        1
# 87.00        1
# 19.35        1
# Name: price, Length: 147, dtype: int64

# %%
pc=df.price.value_counts()[:10]
pc
# Out:
# 7.0     52314
# 16.5    44351
# 10.5    40590
# 13.5    33707
# 9.0     30884
# 27.5    28221
# 19.5    26591
# 22.5    26568
# 26.0    26226
# 9.5     22738
# 11.0    21419
# 8.5     18270
# 7.5     17951
# 5.0     14084
# 8.0     13885
# 16.0    12654
# 15.0    12470
# 32.5    11496
# 11.5    11044
# 34.0     9792
# 30.0     7685
# 10.0     7069
# Name: price, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(pc.index,pc.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Group By

# %%
df.isnull().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# date_time               0
# dtype: int64

# %%
df=df.dropna()

# %%
a=df.groupby("name")["price"].max().sort_values(ascending=False)

# %%
b=df.groupby("name")["price"].sum().sort_values(ascending=False)

# %%
print(type(a))
a
# Out:
# <class 'pandas.core.series.Series'>
# name
# Lux Black XL    97.5
# Black SUV       89.5
# UberXL          76.0
# Lux Black       75.0
# Black           68.5
# Lyft XL         65.0
# Lux             55.0
# UberX           44.0
# WAV             44.0
# UberPool        42.5
# Lyft            38.5
# Shared          22.5
# Name: price, dtype: float64

# %%
a.sort_values(ascending=False)
# Out:
# name
# Lux Black XL    97.5
# Black SUV       89.5
# UberXL          76.0
# Lux Black       75.0
# Black           68.5
# Lyft XL         65.0
# Lux             55.0
# UberX           44.0
# WAV             44.0
# UberPool        42.5
# Lyft            38.5
# Shared          22.5
# Name: price, dtype: float64

# %%
plt.pie(a.values, labels=a.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bca425a9d0>,
#   <matplotlib.patches.Wedge at 0x1bca4268130>,
#   <matplotlib.patches.Wedge at 0x1bca4268850>,
#   <matplotlib.patches.Wedge at 0x1bca4268f70>,
#   <matplotlib.patches.Wedge at 0x1bca42766d0>,
#   <matplotlib.patches.Wedge at 0x1bca4276df0>,
#   <matplotlib.patches.Wedge at 0x1bca4283550>,
#   <matplotlib.patches.Wedge at 0x1bca4283c70>,
#   <matplotlib.patches.Wedge at 0x1bca42923d0>,
#   <matplotlib.patches.Wedge at 0x1bca4292af0>,
#   <matplotlib.patches.Wedge at 0x1bca425a9a0>,
#   <matplotlib.patches.Wedge at 0x1bca42a0940>],
#  [Text(1.0014115392355405, 0.4551647274184434, 'Lux Black XL'),
#   Text(0.35225386680390663, 1.0420735162749775, 'Black SUV'),
#   Text(-0.4265037243000831, 1.013949985530923, 'UberXL'),
#   Text(-0.9589802942713102, 0.5388476549074994, 'Lux Black'),
#   Text(-1.0926138448014546, -0.1272595228192501, 'Black'),
#   Text(-0.8412723104592975, -0.7087036754910161, 'Lyft XL'),
#   Text(-0.37270231113023095, -1.0349362237733226, 'Lux'),
#   Text(0.09613765166804504, -1.0957908340243379, 'UberX'),
#   Text(0.5006756264751017, -0.9794508242141433, 'WAV'),
#   Text(0.8271559839597571, -0.7251296285489692, 'UberPool'),
#   Text(1.0273977136993142, -0.3930062822467629, 'Lyft'),
#   Text(1.0946736704307605, -0.10811824668226491, 'Shared')],
#  [Text(0.5462244759466583, 0.2482716695009691, '13.6%'),
#   Text(0.1921384728021309, 0.5684037361499876, '12.5%'),
#   Text(-0.23263839507277256, 0.5530636284714124, '10.6%'),
#   Text(-0.5230801605116236, 0.2939169026768178, '10.4%'),
#   Text(-0.5959711880735206, -0.0694142851741364, '9.5%'),
#   Text(-0.4588758057050713, -0.38656564117691783, '9.1%'),
#   Text(-0.20329216970739866, -0.5645106675127213, '7.7%'),
#   Text(0.052438719091660924, -0.5977040912860023, '6.1%'),
#   Text(0.2730957962591463, -0.5342459041168054, '6.1%'),
#   Text(0.45117599125077656, -0.3955252519358014, '5.9%'),
#   Text(0.5603987529268986, -0.21436706304368883, '5.4%'),
#   Text(0.5970947293258693, -0.05897358909941722, '3.1%')])

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693065      1.00     Uber  1543708385534      North End          West End
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693065    9.5               1.0  353e6566-b272-479e-a9c6-98bd6cb23f25
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693065  9a0e7b09-b92b-4c41-9779-2ad22b4d779d           WAV
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 693065 2018-12-01 23:53:05.533999872
# 693066 2018-12-01 23:53:05.533999872
# 693067 2018-12-01 23:53:05.533999872
# 693069 2018-12-01 23:53:05.533999872
# 693070 2018-12-01 23:53:05.533999872
#
# [637976 rows x 11 columns]

# %% [markdown]
# # To segregate date and time

# %%
df['date_time'] = pd.to_datetime(df['time_stamp']/1000, unit='s')
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693065      1.00     Uber  1543708385534      North End          West End
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693065    9.5               1.0  353e6566-b272-479e-a9c6-98bd6cb23f25
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693065  9a0e7b09-b92b-4c41-9779-2ad22b4d779d           WAV
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time
# 0      2018-12-16 09:30:07.890000128
# 1      2018-11-27 02:00:23.676999936
# 2      2018-11-28 01:00:22.197999872
# 3      2018-11-30 04:53:02.749000192
# 4      2018-11-29 03:49:20.223000064
# ...                              ...
# 693065 2018-12-01 23:53:05.533999872
# 693066 2018-12-01 23:53:05.533999872
# 693067 2018-12-01 23:53:05.533999872
# 693069 2018-12-01 23:53:05.533999872
# 693070 2018-12-01 23:53:05.533999872
#
# [637976 rows x 11 columns]

# %%
df['date']=pd.to_datetime(df['date_time']).dt.date
df['time']=pd.to_datetime(df['date_time']).dt.time
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693065      1.00     Uber  1543708385534      North End          West End
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# 0         5.0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# 1        11.0               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d
# 2         7.0               1.0  981a3613-77af-4620-a42a-0c0866077d1e
# 3        26.0               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# 4         9.0               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# ...       ...               ...                                   ...
# 693065    9.5               1.0  353e6566-b272-479e-a9c6-98bd6cb23f25
# 693066   13.0               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067    9.5               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693069   27.0               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070   10.0               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id          name  \
# 0                                  lyft_line        Shared
# 1                               lyft_premier           Lux
# 2                                       lyft          Lyft
# 3                                lyft_luxsuv  Lux Black XL
# 4                                  lyft_plus       Lyft XL
# ...                                      ...           ...
# 693065  9a0e7b09-b92b-4c41-9779-2ad22b4d779d           WAV
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2      UberPool
#
#                            date_time        date             time
# 0      2018-12-16 09:30:07.890000128  2018-12-16  09:30:07.890000
# 1      2018-11-27 02:00:23.676999936  2018-11-27  02:00:23.676999
# 2      2018-11-28 01:00:22.197999872  2018-11-28  01:00:22.197999
# 3      2018-11-30 04:53:02.749000192  2018-11-30  04:53:02.749000
# 4      2018-11-29 03:49:20.223000064  2018-11-29  03:49:20.223000
# ...                              ...         ...              ...
# 693065 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693066 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693067 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693069 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693070 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
#
# [637976 rows x 13 columns]

# %%
df.groupby("cab_type")["distance"].mean()
# Out:
# cab_type
# Lyft    2.186976
# Uber    2.191386
# Name: distance, dtype: float64

# %%
df.groupby("cab_type")["distance"].max()
# Out:
# cab_type
# Lyft    6.33
# Uber    7.86
# Name: distance, dtype: float64

# %%
df.groupby("cab_type")["distance"].min()
# Out:
# cab_type
# Lyft    0.39
# Uber    0.02
# Name: distance, dtype: float64

# %% [markdown]
# # Extra Questions with their plots

# %% [markdown]
# 1.Rides of Uber with surge multiplier 1

# %%
df5=df[(df.surge_multiplier==1.0) & (df.cab_type=="Uber")]
df5
# Out:
#         distance cab_type     time_stamp destination     source  price  \
# 12          1.11     Uber  1543615981179    West End  North End   12.0
# 13          1.11     Uber  1544698211014    West End  North End   16.0
# 14          1.11     Uber  1544728503935    West End  North End    7.5
# 15          1.11     Uber  1545004511430    West End  North End    7.5
# 16          1.11     Uber  1544748007961    West End  North End   26.0
# ...          ...      ...            ...         ...        ...    ...
# 693065      1.00     Uber  1543708385534   North End   West End    9.5
# 693066      1.00     Uber  1543708385534   North End   West End   13.0
# 693067      1.00     Uber  1543708385534   North End   West End    9.5
# 693069      1.00     Uber  1543708385534   North End   West End   27.0
# 693070      1.00     Uber  1543708385534   North End   West End   10.0
#
#         surge_multiplier                                    id  \
# 12                   1.0  009e9c53-074d-43cf-aef2-0fbc7a47ed3d
# 13                   1.0  23f145da-f0c1-4d1f-a184-496bc003a7db
# 14                   1.0  357559cb-8c58-4278-a41a-e33b2e0997a3
# 15                   1.0  50ef1165-9d23-416c-a65c-18906207b295
# 16                   1.0  91c4861c-1780-42b0-bca1-bbd64a422cc3
# ...                  ...                                   ...
# 693065               1.0  353e6566-b272-479e-a9c6-98bd6cb23f25
# 693066               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693069               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id       name  \
# 12      6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL
# 13      6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 14      55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 15      9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV
# 16      6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# ...                                      ...        ...
# 693065  9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL
# 693067  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 693069  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 693070  997acbb5-e102-41e1-b155-9df7de0a73f2   UberPool
#
#                            date_time        date             time
# 12     2018-11-30 22:13:01.178999808  2018-11-30  22:13:01.178999
# 13     2018-12-13 10:50:11.013999872  2018-12-13  10:50:11.013999
# 14     2018-12-13 19:15:03.935000064  2018-12-13  19:15:03.935000
# 15     2018-12-16 23:55:11.430000128  2018-12-16  23:55:11.430000
# 16     2018-12-14 00:40:07.960999936  2018-12-14  00:40:07.960999
# ...                              ...         ...              ...
# 693065 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693066 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693067 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693069 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
# 693070 2018-12-01 23:53:05.533999872  2018-12-01  23:53:05.533999
#
# [330568 rows x 13 columns]

# %% [markdown]
# 2.Rides of car name taxi

# %%
df2=df[df.name=='Taxi']
df2
# Out:
# Empty DataFrame
# Columns: [distance, cab_type, time_stamp, destination, source, price, surge_multiplier, id, product_id, name, date_time, date, time]
# Index: []

# %% [markdown]
# 3.Top 10 rides with distance more than 2 miles and price more than 20$

# %%
df2=df[(df.distance>2.0) & (df.price>20)][1:10]
df2
# Out:
#     distance cab_type     time_stamp              destination  \
# 30      2.48     Uber  1544817908118            South Station
# 35      3.24     Lyft  1543743182105  Northeastern University
# 37      2.94     Uber  1543638777654                   Fenway
# 42      2.94     Uber  1543286002090                   Fenway
# 80      3.39     Uber  1545002712654            North Station
# 81      3.39     Uber  1544703016070            North Station
# 88      3.39     Uber  1543532587413            North Station
# 89      3.39     Uber  1545036611905            North Station
# 90      2.82     Lyft  1543542476058                 West End
#
#                source  price  surge_multiplier  \
# 30        Beacon Hill   27.5               1.0
# 35      North Station   26.0               1.0
# 37      North Station   29.5               1.0
# 42      North Station   22.0               1.0
# 80  Boston University   34.0               1.0
# 81  Boston University   26.0               1.0
# 88  Boston University   36.0               1.0
# 89  Boston University   27.5               1.0
# 90             Fenway   22.5               1.0
#
#                                       id  \
# 30  8674e79f-4c5b-4a2e-8327-a68997d5d740
# 35  72fb8672-a823-447e-ae15-fd51aef9db66
# 37  39f120bf-ddc0-4d27-8ab4-bb7d46ecf8e3
# 42  c7d4bb19-3c35-46c7-ad3c-f00a03ccfdfe
# 80  a841f68a-a00f-456a-a3f2-2a4f2f2917d6
# 81  aaf17c52-066b-4449-abac-274132b8ffbf
# 88  bcb04ae7-e199-495f-a22e-4f24dcf9088c
# 89  ef16279b-5893-4ea1-bf62-0548a6a541e7
# 90  60f7fd10-aa55-42a8-9b19-2f8bb457459b
#
#                               product_id       name  \
# 30  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 35                              lyft_lux  Lux Black
# 37  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 42  6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 80  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 81  6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 88  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 89  6c84fd89-3f11-4782-9b50-97c468b19529      Black
# 90                              lyft_lux  Lux Black
#
#                        date_time        date             time
# 30 2018-12-14 20:05:08.118000128  2018-12-14  20:05:08.118000
# 35 2018-12-02 09:33:02.104999936  2018-12-02  09:33:02.104999
# 37 2018-12-01 04:32:57.654000128  2018-12-01  04:32:57.654000
# 42 2018-11-27 02:33:22.089999872  2018-11-27  02:33:22.089999
# 80 2018-12-16 23:25:12.654000128  2018-12-16  23:25:12.654000
# 81 2018-12-13 12:10:16.069999872  2018-12-13  12:10:16.069999
# 88 2018-11-29 23:03:07.413000192  2018-11-29  23:03:07.413000
# 89 2018-12-17 08:50:11.904999936  2018-12-17  08:50:11.904999
# 90 2018-11-30 01:47:56.058000128  2018-11-30  01:47:56.058000

# %% [markdown]
# 4.Sort rides by highest price surge multiplier

# %%
df.sort_values(by=['price','surge_multiplier'],ascending=False)
# Out:
#         distance cab_type     time_stamp         destination  \
# 597071      4.43     Lyft  1543714082123              Fenway
# 28083       3.89     Lyft  1543441295635  Financial District
# 75919       3.75     Lyft  1544721314374  Financial District
# 271719      5.39     Lyft  1543453328714   Boston University
# 280566      5.39     Lyft  1543356201754   Boston University
# ...          ...      ...            ...                 ...
# 677015      0.99     Lyft  1545115213953  Financial District
# 679085      0.66     Lyft  1543822681966       South Station
# 679217      1.33     Lyft  1543350442133       South Station
# 679502      1.54     Lyft  1543289782115       South Station
# 683795      2.93     Lyft  1543729677193              Fenway
#
#                     source  price  surge_multiplier  \
# 597071  Financial District   97.5               2.0
# 28083               Fenway   92.0               2.0
# 75919    Boston University   92.0               2.0
# 271719  Financial District   92.0               2.0
# 280566  Financial District   92.0               2.0
# ...                    ...    ...               ...
# 677015    Haymarket Square    2.5               1.0
# 679085    Theatre District    2.5               1.0
# 679217            Back Bay    2.5               1.0
# 679502         Beacon Hill    2.5               1.0
# 683795            West End    2.5               1.0
#
#                                           id   product_id          name  \
# 597071  ba1593a1-e4fd-4c7a-a011-e2d4fccbf081  lyft_luxsuv  Lux Black XL
# 28083   edb9ba13-b129-487f-be93-2e3abdd700a3  lyft_luxsuv  Lux Black XL
# 75919   e0032a2b-c328-457e-adb5-79c3d83064a8  lyft_luxsuv  Lux Black XL
# 271719  6f17623a-f97c-4379-9188-4f3e07d1c48e  lyft_luxsuv  Lux Black XL
# 280566  fe9f56b5-e54a-48b4-b702-4e625adcf0ab  lyft_luxsuv  Lux Black XL
# ...                                      ...          ...           ...
# 677015  7ed35758-7e46-4602-a0fe-d46276142fab    lyft_line        Shared
# 679085  085a21fd-6b7a-4ffe-bc57-b467e4ef7982    lyft_line        Shared
# 679217  eebce30a-3d96-4833-a8be-6a4c1c14b264    lyft_line        Shared
# 679502  3f71f02f-e270-4140-ab47-d6ec4ff188f0    lyft_line        Shared
# 683795  68937cd4-b36b-40f0-89d5-3de5288741b9    lyft_line        Shared
#
#                            date_time        date             time
# 597071 2018-12-02 01:28:02.122999808  2018-12-02  01:28:02.122999
# 28083  2018-11-28 21:41:35.635000064  2018-11-28  21:41:35.635000
# 75919  2018-12-13 17:15:14.374000128  2018-12-13  17:15:14.374000
# 271719 2018-11-29 01:02:08.713999872  2018-11-29  01:02:08.713999
# 280566 2018-11-27 22:03:21.753999872  2018-11-27  22:03:21.753999
# ...                              ...         ...              ...
# 677015 2018-12-18 06:40:13.953000192  2018-12-18  06:40:13.953000
# 679085 2018-12-03 07:38:01.966000128  2018-12-03  07:38:01.966000
# 679217 2018-11-27 20:27:22.132999936  2018-11-27  20:27:22.132999
# 679502 2018-11-27 03:36:22.115000064  2018-11-27  03:36:22.115000
# 683795 2018-12-02 05:47:57.193000192  2018-12-02  05:47:57.193000
#
# [637976 rows x 13 columns]

# %% [markdown]
# 5.Number of rides which have source Boston University,destination Financial District and price less than 15$

# %%
df7 = df[(df.source=="Boston University") & (df.destination=="Financial District") & (df.price <= 15.0)]
df7
df7.count()
# Out:
# distance            3305
# cab_type            3305
# time_stamp          3305
# destination         3305
# source              3305
# price               3305
# surge_multiplier    3305
# id                  3305
# product_id          3305
# name                3305
# date_time           3305
# date                3305
# time                3305
# dtype: int64

# %% [markdown]
# 6.Histogram of date

# %%
plt.figure(figsize=(11,7))
plt.hist(df.date)
# Out:
# (array([167005.,  96766.,  82978.,  52950.,      0.,   1529.,   2534.,
#          35496.,  82676., 116042.]),
#  array([17861. , 17863.2, 17865.4, 17867.6, 17869.8, 17872. , 17874.2,
#         17876.4, 17878.6, 17880.8, 17883. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 7.Pie chart of percentage of cab types used

# %%
perct_dist = df.name.value_counts()
perct_dist
# Out:
# UberXL          55096
# WAV             55096
# Black SUV       55096
# Black           55095
# UberX           55094
# UberPool        55091
# Lux             51235
# Lyft            51235
# Lux Black XL    51235
# Lyft XL         51235
# Lux Black       51235
# Shared          51233
# Name: name, dtype: int64

# %%
index = perct_dist.index
sizes = perct_dist.values
print(index)
print(sizes)
# Out:
# Index(['UberXL', 'WAV', 'Black SUV', 'Black', 'UberX', 'UberPool', 'Lux',
#        'Lyft', 'Lux Black XL', 'Lyft XL', 'Lux Black', 'Shared'],
#       dtype='object')
# [55096 55096 55096 55095 55094 55091 51235 51235 51235 51235 51235 51233]

# %%
plt.pie(sizes, labels=index, autopct='%1.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bcaf76f5b0>,
#   <matplotlib.patches.Wedge at 0x1bcaf76fee0>,
#   <matplotlib.patches.Wedge at 0x1bcaf77f8e0>,
#   <matplotlib.patches.Wedge at 0x1bcaf78a2b0>,
#   <matplotlib.patches.Wedge at 0x1bcaf78ac40>,
#   <matplotlib.patches.Wedge at 0x1bcaf797610>,
#   <matplotlib.patches.Wedge at 0x1bcaf797fa0>,
#   <matplotlib.patches.Wedge at 0x1bcaf7a5970>,
#   <matplotlib.patches.Wedge at 0x1bcaf7b5340>,
#   <matplotlib.patches.Wedge at 0x1bcaf7b5cd0>,
#   <matplotlib.patches.Wedge at 0x1bcaf76f580>,
#   <matplotlib.patches.Wedge at 0x1bcaf8f0040>],
#  [Text(1.0597627504857359, 0.2947929997182905, 'UberXL'),
#   Text(0.7553116107499992, 0.799690171670405, 'WAV'),
#   Text(0.23387277198155568, 1.0748504670537495, 'Black SUV'),
#   Text(-0.35474844530132504, 1.041226939987769, 'Black'),
#   Text(-0.841451521286754, 0.7084908872555861, 'UberX'),
#   Text(-1.0864298865317048, 0.17225011364497578, 'UberPool'),
#   Text(-1.0270074064013839, -0.39402510985558137, 'Lux'),
#   Text(-0.7085198984448698, -0.841427093400059, 'Lyft'),
#   Text(-0.21342775843497525, -1.0790961921577806, 'Lux Black XL'),
#   Text(0.334863072015536, -1.0477913547077577, 'Lyft XL'),
#   Text(0.7996864236395946, -0.755315578977764, 'Lux Black'),
#   Text(1.0651784093739083, -0.27458141998990193, 'Shared')],
#  [Text(0.5780524093558559, 0.16079618166452206, '8.64%'),
#   Text(0.41198815131818134, 0.43619463909294814, '8.64%'),
#   Text(0.12756696653539398, 0.5862820729384087, '8.64%'),
#   Text(-0.19349915198254092, 0.5679419672660557, '8.64%'),
#   Text(-0.45897355706550214, 0.38644957486668324, '8.64%'),
#   Text(-0.5925981199263844, 0.09395460744271404, '8.64%'),
#   Text(-0.5601858580371184, -0.21492278719395344, '8.03%'),
#   Text(-0.38646539915174716, -0.4589602327636685, '8.03%'),
#   Text(-0.11641514096453194, -0.588597922995153, '8.03%'),
#   Text(0.1826525847357469, -0.5715225571133223, '8.03%'),
#   Text(0.4361925947125061, -0.4119903158060531, '8.03%'),
#   Text(0.5810064051130408, -0.14977168363085558, '8.03%')])

# %% [markdown]
# 8.price bar chart

# %%
pc=df.price.value_counts()

# %%
pc=df.price.value_counts()[:10]
pc
# Out:
# 7.0     52314
# 16.5    44351
# 10.5    40590
# 13.5    33707
# 9.0     30884
# 27.5    28221
# 19.5    26591
# 22.5    26568
# 26.0    26226
# 9.5     22738
# 11.0    21419
# 8.5     18270
# 7.5     17951
# 5.0     14084
# 8.0     13885
# 16.0    12654
# 15.0    12470
# 32.5    11496
# 11.5    11044
# 34.0     9792
# 30.0     7685
# 10.0     7069
# Name: price, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.barplot(pc.index,pc.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 9.surge multiplier other than 1 bar graph

# %%
pc=df.surge_multiplier.value_counts()

# %%
pc=df.surge_multiplier.value_counts()[1.25:]
pc
# Out:
# 1.25    11085
# 1.50     5065
# 1.75     2420
# 2.00     2239
# 2.50      154
# 3.00       12
# Name: surge_multiplier, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.barplot(pc.index,pc.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10.Date bar graph

# %%
pc=df.date.value_counts()

# %%
pc=df.date.value_counts()
pc
# Out:
# 2018-11-27    70135
# 2018-11-28    67842
# 2018-11-29    55222
# 2018-12-01    41680
# 2018-11-30    41544
# 2018-12-16    41359
# 2018-12-17    41354
# 2018-12-14    41344
# 2018-12-15    41332
# 2018-12-03    41323
# 2018-12-02    41298
# 2018-12-13    35496
# 2018-12-18    33329
# 2018-11-26    29028
# 2018-12-04    11627
# 2018-12-10     2534
# 2018-12-09     1529
# Name: date, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.barplot(pc.index,pc.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 11.Extra money earned from surge

# %%
df2=df[df["surge_multiplier"]>1.0]
df3=df2.price.sum()
df2.shape[0],df3
f=df3-(df3/df2.shape[0])
f
# Out:
# 583852.1630512514

# %% [markdown]
# 12.What is the date when surge was max

# %%
df7 = df[(2018 in df.date) & (df.surge_multiplier==3.0)]
df7
# Out:
#         distance cab_type     time_stamp         destination  \
# 71555       4.64     Lyft  1543356743100   Boston University
# 71556       4.64     Lyft  1545003618739   Boston University
# 160088      2.30     Lyft  1543337662045    Haymarket Square
# 160091      2.30     Lyft  1543337662045    Haymarket Square
# 289791      1.84     Lyft  1543309401922       South Station
# 289792      1.84     Lyft  1545015903672       South Station
# 499099      3.16     Lyft  1543408328522           North End
# 499100      3.16     Lyft  1543408328522           North End
# 537448      4.39     Lyft  1543293741898  Financial District
# 537450      4.39     Lyft  1544758807486  Financial District
# 649747      2.33     Lyft  1543672678833   Boston University
# 649750      2.33     Lyft  1543672678833   Boston University
#
#                    source  price  surge_multiplier  \
# 71555    Theatre District   62.5               3.0
# 71556    Theatre District   38.0               3.0
# 160088           Back Bay   42.5               3.0
# 160091           Back Bay   26.0               3.0
# 289791           Back Bay   22.5               3.0
# 289792           Back Bay   38.0               3.0
# 499099           Back Bay   55.0               3.0
# 499100           Back Bay   27.5               3.0
# 537448  Boston University   65.0               3.0
# 537450  Boston University   38.5               3.0
# 649747        Beacon Hill   42.5               3.0
# 649750        Beacon Hill   26.0               3.0
#
#                                           id product_id     name  \
# 71555   b72cc6c0-c0a1-4aaf-aa0a-b0fe2b64d0c8  lyft_plus  Lyft XL
# 71556   cb7f3543-7f95-4042-a20b-971d1d38acb4       lyft     Lyft
# 160088  26f21ac1-edcc-4467-80e2-3d4676cbc0fe  lyft_plus  Lyft XL
# 160091  bcef8376-da26-4afd-8c32-e4f687a01824       lyft     Lyft
# 289791  29c15ed1-38be-4b26-846f-b51898b79419       lyft     Lyft
# 289792  bc4bb4d9-ff62-45c6-9d85-8593e6bd8a5f  lyft_plus  Lyft XL
# 499099  6cc9f119-3263-42af-b919-355d23a55e31  lyft_plus  Lyft XL
# 499100  8840e1a9-b116-4c13-a34a-e31ba3fff549       lyft     Lyft
# 537448  358f083b-e2b5-4a8c-b98c-497b046f6743  lyft_plus  Lyft XL
# 537450  737dafa2-da81-41bc-adbb-1b2ed5ca90da       lyft     Lyft
# 649747  3e8cde11-2963-4267-88ed-f256c6e1f297  lyft_plus  Lyft XL
# 649750  b71ea9d2-87f5-4205-b7ea-84aa0051b3f0       lyft     Lyft
#
#                            date_time        date             time
# 71555  2018-11-27 22:12:23.100000000  2018-11-27  22:12:23.100000
# 71556  2018-12-16 23:40:18.739000064  2018-12-16  23:40:18.739000
# 160088 2018-11-27 16:54:22.045000192  2018-11-27  16:54:22.045000
# 160091 2018-11-27 16:54:22.045000192  2018-11-27  16:54:22.045000
# 289791 2018-11-27 09:03:21.921999872  2018-11-27  09:03:21.921999
# 289792 2018-12-17 03:05:03.672000000  2018-12-17  03:05:03.672000
# 499099 2018-11-28 12:32:08.522000128  2018-11-28  12:32:08.522000
# 499100 2018-11-28 12:32:08.522000128  2018-11-28  12:32:08.522000
# 537448 2018-11-27 04:42:21.898000128  2018-11-27  04:42:21.898000
# 537450 2018-12-14 03:40:07.486000128  2018-12-14  03:40:07.486000
# 649747 2018-12-01 13:57:58.832999936  2018-12-01  13:57:58.832999
# 649750 2018-12-01 13:57:58.832999936  2018-12-01  13:57:58.832999

# %% [markdown]
# 13.Group by of destination and price max

# %%
a=df.groupby("destination")["price"].max().sort_values(ascending=False)

# %%
b=df.groupby("destination")["price"].sum().sort_values(ascending=False)

# %%
print(type(a))
a
# Out:
# <class 'pandas.core.series.Series'>
# destination
# Fenway                     97.5
# Boston University          92.0
# Financial District         92.0
# Northeastern University    89.5
# North Station              80.5
# West End                   80.0
# Back Bay                   75.0
# North End                  75.0
# Theatre District           75.0
# South Station              68.0
# Haymarket Square           67.5
# Beacon Hill                65.0
# Name: price, dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("googleplaystore[1].csv")
print(type(df))

#data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.Rating.describe()
# Out:
# count    8893.000000
# mean        4.189542
# std         0.545452
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
value_Rating=df.Rating.value_counts()
value_Rating
# Out:
# 4.4     1032
# 4.3     1016
# 4.5      977
# 4.2      888
# 4.6      768
# 4.1      657
# 4.0      539
# 4.7      484
# 3.9      372
# 3.8      293
# 5.0      271
# 3.7      231
# 4.8      228
# 3.6      169
# 3.5      157
# 3.4      127
# 3.3      101
# 4.9       87
# 3.0       82
# 3.1       69
# 3.2       64
# 2.9       45
# 2.8       40
# 2.6       24
# 2.7       23
# 2.5       20
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       12
# 2.0       12
# 1.7        8
# 1.8        8
# 2.1        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
print(len(value_Rating))
# Out:
# 40

# %%
top_10_value_Rating=value_Rating.iloc[:10] 
top_10_value_Rating
# Out:
# 4.4    1032
# 4.3    1016
# 4.5     977
# 4.2     888
# 4.6     768
# 4.1     657
# 4.0     539
# 4.7     484
# 3.9     372
# 3.8     293
# Name: Rating, dtype: int64

# %%
df1=df.iloc[:,0:2]
df1
# Out:
#                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# [10358 rows x 2 columns]

# %%
df1=df.iloc[0:5,0:2]
df1
# Out:
#                                                  App        Category
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                Coloring book moana  ART_AND_DESIGN
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN

# %%
df1=df.iloc[:,:]
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2=df.loc[df.Rating==4.0]
df2
# Out:
#                                                  App           Category  \
# 20                       Logo Maker - Small Business     ART_AND_DESIGN
# 39     How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 50                              Real Tractor Farming  AUTO_AND_VEHICLES
# 58                                 Restart Navigator  AUTO_AND_VEHICLES
# 66                                  Used Cars Mexico  AUTO_AND_VEHICLES
# ...                                              ...                ...
# 10802                            FR: My Famous Lover             FAMILY
# 10814                           FR: My Secret Pets!              FAMILY
# 10817                           HTC Sense Input - FR              TOOLS
# 10826      Frim: get new friends on local chat rooms             SOCIAL
# 10834                                  FR Calculator             FAMILY
#
#        Rating Reviews                Size    Installs  Type Price  \
# ...

# %%
df2=df.loc[df.Rating==4.4][0:10]    
df2
# Out:
#                                                   App           Category  \
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 14    3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 42                         Textgram - write on photos     ART_AND_DESIGN
# 56                          Gas Prices (Germany only)  AUTO_AND_VEHICLES
# 81                         PakWheels: Buy & Sell Cars  AUTO_AND_VEHICLES
# 85  CarMax – Cars for Sale: Search Used Car Inventory  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
#
#     Rating Reviews                Size     Installs  Type Price  \
# 5      4.4     167                5.6M      50,000+  Free     0
# ...

# %%
df3=df[(df.Rating==4.4) & (df.Installs=='1,000,000+')]
df3
# Out:
#                                                      App           Category  \
# 8                                   Garden Coloring Book     ART_AND_DESIGN
# 10                               Text on Photo - Fonteee     ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 81                            PakWheels: Buy & Sell Cars  AUTO_AND_VEHICLES
# 85     CarMax – Cars for Sale: Search Used Car Inventory  AUTO_AND_VEHICLES
# ...                                                  ...                ...
# 10434                                  Talking Husky Dog             FAMILY
# 10526          Fairy Kingdom: World of Magic and Farming             FAMILY
# 10712                              Lalafo Pulsuz Elanlar           SHOPPING
# 10720                 Firefox Focus: The privacy browser      COMMUNICATION
# 10726                                    Thumbnail Maker        PHOTOGRAPHY
#
# ...

# %%
df4=df[(df.Rating==4.4) | (df.Installs=='1,000,000+')]
df4
# Out:
#                                                     App        Category  \
# 5                            Paper flowers instructions  ART_AND_DESIGN
# 7                                      Infinite Painter  ART_AND_DESIGN
# 8                                  Garden Coloring Book  ART_AND_DESIGN
# 10                              Text on Photo - Fonteee  ART_AND_DESIGN
# 11              Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN
# ...                                                 ...             ...
# 10793                                         Sid Story            GAME
# 10796  Inf VPN - Global Proxy & Unlimited Free WIFI VPN           TOOLS
# 10797                             Fuel Rewards® program       LIFESTYLE
# 10803                      Fatal Raid - No.1 Mobile FPS            GAME
# 10809             Castle Clash: RPG War and Strategy FR          FAMILY
#
#        Rating Reviews  Size    Installs  Type Price Content Rating  \
# ...

# %%
df5=df.loc[(df.Rating==4.4) & (df.Type=='Free') & (df.Installs=="1,000,000+")][:10]
df5
# Out:
#                                                    App             Category  \
# 8                                 Garden Coloring Book       ART_AND_DESIGN
# 10                             Text on Photo - Fonteee       ART_AND_DESIGN
# 11             Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 81                          PakWheels: Buy & Sell Cars    AUTO_AND_VEHICLES
# 85   CarMax – Cars for Sale: Search Used Car Inventory    AUTO_AND_VEHICLES
# 148                                         Book store  BOOKS_AND_REFERENCE
# 171                                 All Maths Formulas  BOOKS_AND_REFERENCE
# 181                         English-Myanmar Dictionary  BOOKS_AND_REFERENCE
# 182                          Golden Dictionary (EN-AR)  BOOKS_AND_REFERENCE
# 183                       All Language Translator Free  BOOKS_AND_REFERENCE
#
#      Rating Reviews                Size    Installs  Type Price  \
# 8       4.4   13791                 33M  1,000,000+  Free     0
# ...

# %%
####
df2=df[(df.Size>'2') & (df.Reviews<'50000')]
df2
# Out:
#                                     App             Category  Rating Reviews  \
# 3                 Sketch - Draw & Paint       ART_AND_DESIGN     4.5  215644
# 5            Paper flowers instructions       ART_AND_DESIGN     4.4     167
# 7                      Infinite Painter       ART_AND_DESIGN     4.1   36815
# 8                  Garden Coloring Book       ART_AND_DESIGN     4.4   13791
# 9         Kids Paint Free - Drawing Fun       ART_AND_DESIGN     4.7     121
# ...                                 ...                  ...     ...     ...
# 10832                          FR Tides              WEATHER     3.8    1195
# 10833                       Chemin (fr)  BOOKS_AND_REFERENCE     4.8      44
# 10836                  Sya9a Maroc - FR               FAMILY     4.5      38
# 10837  Fr. Mike Schmitz Audio Teachings               FAMILY     5.0       4
# 10839     The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5     114
#
# ...

# %%
df["Category"].value_counts()
# Out:
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
df.sort_values(by=['Installs'])
# Out:
#                                            App          Category  Rating  \
# 9148                 Command & Conquer: Rivals            FAMILY     NaN
# 6692                             cronometra-br      PRODUCTIVITY     NaN
# 9719                              EP Cook Book           MEDICAL     NaN
# 9934         I'm Rich/Eu sou Rico/أنا غني/我很有錢         LIFESTYLE     NaN
# 9337                  EG | Explore Folegandros  TRAVEL_AND_LOCAL     NaN
# ...                                        ...               ...     ...
# 1869                          Candy Crush Saga              GAME     4.4
# 1885                                       Pou              GAME     4.3
# 1908                            My Talking Tom              GAME     4.5
# 3994                          Candy Crush Saga            FAMILY     4.4
# 10472  Life Made WI-Fi Touchscreen Photo Frame               1.9    19.0
#
#         Reviews                Size      Installs  Type     Price  \
# ...

# %%
df.sort_values(by=['Installs'],ascending=False)
# Out:
#                                            App            Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                 1.9    19.0
# 4115                                   Twitter  NEWS_AND_MAGAZINES     4.3
# 347              imo free video calls and chat       COMMUNICATION     4.3
# 3265              Gboard - the Google Keyboard               TOOLS     4.2
# 4005   Clean Master- Space Cleaner & Antivirus               TOOLS     4.7
# ...                                        ...                 ...     ...
# 9719                              EP Cook Book             MEDICAL     NaN
# 5945                Ain Arabic Kids Alif Ba ta              FAMILY     NaN
# 8871                    Test Application DT 02      ART_AND_DESIGN     NaN
# 5307                   Ak Parti Yardım Toplama              SOCIAL     NaN
# 9148                 Command & Conquer: Rivals              FAMILY     NaN
#
#         Reviews                Size      Installs  Type     Price  \
# ...

# %%
df.sort_values(by=['Rating','Installs'],ascending=False)
# Out:
#                                            App   Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame        1.9    19.0    3.0M
# 633                      Spine- The dating app     DATING     5.0       5
# 1028                          SUMMER SONIC app     EVENTS     5.0       4
# 2271                            FHR 5-Tier 2.0    MEDICAL     5.0       2
# 5125                     Ag Valley Cooperative   BUSINESS     5.0       6
# ...                                        ...        ...     ...     ...
# 9719                              EP Cook Book    MEDICAL     NaN       0
# 9905                               Eu sou Rico    FINANCE     NaN       0
# 9917                               Eu Sou Rico    FINANCE     NaN       0
# 9934         I'm Rich/Eu sou Rico/أنا غني/我很有錢  LIFESTYLE     NaN       0
# 9148                 Command & Conquer: Rivals     FAMILY     NaN       0
#
#                      Size Installs  Type     Price Content Rating  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df.Rating)
# Out:
# (array([1.950e+02, 6.859e+03, 1.838e+03, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Installs[:10])
# Out:
# (array([2., 1., 0., 1., 0., 1., 1., 0., 2., 2.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
perct_Type = df.Type.value_counts()[:10]
perct_Type
# Out:
# Free    9591
# Paid     765
# 0          1
# Name: Type, dtype: int64

# %%
index = perct_Type.index
sizes = perct_Type.values
print(index)
print(sizes)
# Out:
# Index(['Free', 'Paid', '0'], dtype='object')
# [9591  765    1]

# %%
plt.pie(sizes, labels=index, autopct='%1.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x233a50ba040>,
# ...
#  [Text(-1.0704404799940266, 0.2532926741738855, 'Free'),
#   Text(1.0703635942351382, -0.25361738137603373, 'Paid'),
#   Text(1.099999949381316, -0.000333708110021297, '0')],
#  [Text(-0.5838766254512872, 0.138159640458483, '92.60%'),
#   Text(0.5838346877646208, -0.13833675347783658, '7.39%'),
#   Text(0.5999999723898086, -0.000182022605466162, '0.01%')])

# %%
perct_Category = df.Category.value_counts()[:10]
perct_Category
# Out:
# FAMILY             1943
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: Category, dtype: int64

# %%
index = perct_Category.index
sizes = perct_Category.values
print(index)
print(sizes)
# Out:
# Index(['FAMILY', 'GAME', 'TOOLS', 'BUSINESS', 'MEDICAL', 'PRODUCTIVITY',
#        'PERSONALIZATION', 'LIFESTYLE', 'COMMUNICATION', 'FINANCE'],
#       dtype='object')
# [1943 1121  843  427  408  407  388  373  366  360]

# %%
plt.pie(sizes, labels=index, autopct='%1.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x233b681f730>,
# ...
#  [Text(0.6665347278474846, 0.8750608302131229, 'FAMILY'),
#   Text(-0.7887856485721113, 0.7666923767761578, 'GAME'),
#   Text(-1.0861952359335019, -0.17372365824885283, 'TOOLS'),
#   Text(-0.7974456390807835, -0.7576809702711563, 'BUSINESS'),
#   Text(-0.44417296796630273, -1.0063351203888327, 'MEDICAL'),
#   Text(-0.032802883491672936, -1.0995107870478724, 'PRODUCTIVITY'),
#   Text(0.3736111042479546, -1.0346084973470033, 'PERSONALIZATION'),
#   Text(0.7143532686636294, -0.8364803688967176, 'LIFESTYLE'),
#   Text(0.9577927594180523, -0.5409556636235109, 'COMMUNICATION'),
#   Text(1.0840631282879958, -0.18656670090464933, 'FINANCE')],
#  [Text(0.36356439700771886, 0.47730590738897605, '29.28%'),
#   Text(-0.43024671740296977, 0.4181958418779042, '16.89%'),
#   Text(-0.592470128691001, -0.09475835904482881, '12.70%'),
#   Text(-0.4349703485895182, -0.4132805292388125, '6.43%'),
# ...

# %%
perct_Installs = df.Installs.value_counts()[:10]
perct_Installs
# Out:
# 1,000,000+      1485
# 10,000,000+     1132
# 100,000+        1110
# 10,000+          988
# 1,000+           697
# 5,000,000+       683
# 500,000+         515
# 50,000+          461
# 5,000+           425
# 100,000,000+     369
# Name: Installs, dtype: int64

# %%
index = perct_Installs.index
sizes = perct_Installs.values
print(index)
print(sizes)
# Out:
# Index(['1,000,000+', '10,000,000+', '100,000+', '10,000+', '1,000+',
#        '5,000,000+', '500,000+', '50,000+', '5,000+', '100,000,000+'],
#       dtype='object')
# [1485 1132 1110  988  697  683  515  461  425  369]

# %%
plt.pie(sizes, labels=index, autopct='%1.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x233b88d0c70>,
# ...
#  [Text(0.9120914640247614, 0.6148895520767673, '1,000,000+'),
#   Text(-0.07441858368952294, 1.0974797831402845, '10,000,000+'),
#   Text(-0.9031554185553085, 0.6279413108995026, '100,000+'),
#   Text(-1.070913396531527, -0.25128568826996217, '10,000+'),
#   Text(-0.6807230372078767, -0.8640695264933743, '1,000+'),
#   Text(-0.1273547872464255, -1.0926027449011, '5,000,000+'),
#   Text(0.39006528130185636, -1.02851790277219, '500,000+'),
#   Text(0.7516875068216624, -0.8030976852713707, '50,000+'),
#   Text(0.9834263826215641, -0.4928210120965474, '5,000+'),
#   Text(1.0880729782345353, -0.16154625973951986, '100,000,000+')],
#  [Text(0.49750443492259705, 0.3353943011327822, '18.88%'),
#   Text(-0.04059195473973978, 0.5986253362583369, '14.39%'),
#   Text(-0.4926302283028955, 0.3425134423088196, '14.11%'),
#   Text(-0.5841345799262874, -0.1370649208745248, '12.56%'),
#   Text(-0.37130347484066, -0.47131065081456774, '8.86%'),
# ...

# %%
nm=df.Type.value_counts()
nm
# Out:
# Free    9591
# Paid     765
# 0          1
# Name: Type, dtype: int64

# %%
sns.barplot (nm.values,nm.index)
# Out:
# <AxesSubplot:>

# %%
nm=df.Price.value_counts()[:7]
nm
# Out:
# 0        9592
# $0.99     146
# $2.99     125
# $1.99      73
# $4.99      70
# $3.99      60
# $1.49      46
# Name: Price, dtype: int64

# %%
sns.barplot (nm.values,nm.index)
# Out:
# <AxesSubplot:>

# %%
nm=df.Size.value_counts()[:10]
nm
# Out:
# Varies with device    1526
# 11M                    188
# 12M                    186
# 13M                    186
# 14M                    182
# 15M                    174
# 17M                    155
# 26M                    145
# 16M                    143
# 19M                    135
# Name: Size, dtype: int64

# %%
sns.barplot (nm.values,nm.index)
# Out:
# <AxesSubplot:>

# %% [raw]
# df.isnull().sum()

# %%
df=df.dropna()

# %%
a=df.groupby("Genres")["Rating"].max().sort_values(ascending=False)

# %%
print(type(a))
a
# Out:
# <class 'pandas.core.series.Series'>
# Genres
# Action                                   5.0
# Parenting                                5.0
# Dating                                   5.0
# Education                                5.0
# Education;Education                      5.0
#                                         ...
# Parenting;Education                      4.0
# Video Players & Editors;Music & Video    4.0
# Art & Design;Pretend Play                3.9
# Health & Fitness;Action & Adventure      3.9
# Parenting;Brain Games                    3.8
# Name: Rating, Length: 115, dtype: float64

# %%
a.sort_values(ascending=False)
# Out:
# Genres
# Action                                   5.0
# Trivia                                   5.0
# Shopping                                 5.0
# Simulation                               5.0
# Social                                   5.0
#                                         ...
# Parenting;Education                      4.0
# Video Players & Editors;Music & Video    4.0
# Art & Design;Pretend Play                3.9
# Health & Fitness;Action & Adventure      3.9
# Parenting;Brain Games                    3.8
# Name: Rating, Length: 115, dtype: float64
